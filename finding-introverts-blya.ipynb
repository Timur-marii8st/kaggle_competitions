# %%
# !pip install scikit-learn==1.5.2 koolbox
# Out:
# Collecting scikit-learn==1.5.2
#   Downloading scikit_learn-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting koolbox
#   Downloading koolbox-0.1.3-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2) (3.6.0)
# Requirement already satisfied: optuna>=4.2.1 in /usr/local/lib/python3.11/dist-packages (from koolbox) (4.4.0)
# Requirement already satisfied: pandas>=2.2.3 in /usr/local/lib/python3.11/dist-packages (from koolbox) (2.2.3)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.5->scikit-learn==1.5.2) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.5->scikit-learn==1.5.2) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.5->scikit-learn==1.5.2) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.5->scikit-learn==1.5.2) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.5->scikit-learn==1.5.2) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.5->scikit-learn==1.5.2) (2.4.1)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna>=4.2.1->koolbox) (1.16.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna>=4.2.1->koolbox) (6.9.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna>=4.2.1->koolbox) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna>=4.2.1->koolbox) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna>=4.2.1->koolbox) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna>=4.2.1->koolbox) (6.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.3->koolbox) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.3->koolbox) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.3->koolbox) (2025.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna>=4.2.1->koolbox) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna>=4.2.1->koolbox) (4.14.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=2.2.3->koolbox) (1.17.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna>=4.2.1->koolbox) (3.2.3)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.19.5->scikit-learn==1.5.2) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.19.5->scikit-learn==1.5.2) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.19.5->scikit-learn==1.5.2) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.19.5->scikit-learn==1.5.2) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.19.5->scikit-learn==1.5.2) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.11/dist-packages (from Mako->alembic>=1.5.0->optuna>=4.2.1->koolbox) (3.0.2)
# Downloading scikit_learn-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 74.5 MB/s eta 0:00:00
# Downloading koolbox-0.1.3-py3-none-any.whl (18 kB)
# Installing collected packages: scikit-learn, koolbox
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed koolbox-0.1.3 scikit-learn-1.5.2

# %%
# =====================================================================================
# IMPORTS AND CONFIGS, BLYAT
# =====================================================================================
import warnings
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import joblib
import json
import glob
import shutil
import optuna

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import HistGradientBoostingClassifier
from scipy.special import logit
from scipy.stats import rankdata

from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from koolbox import Trainer

# Shut up all the fucking warnings. I'm a professional, I know what I'm doing. Mostly.
warnings.filterwarnings('ignore')

# This is our bible. All sacred numbers and paths are here.
# Change something here, and the whole shaitan-machine might explode. Or not. Who knows.
class CFG:
    TRAIN_PATH = '/kaggle/input/playground-series-s5e7/train.csv'
    TEST_PATH = '/kaggle/input/playground-series-s5e7/test.csv'
    SAMPLE_SUB_PATH = '/kaggle/input/playground-series-s5e7/sample_submission.csv'
    
    ORIGINAL_PATH = "/kaggle/input/extrovert-vs-introvert-behavior-data-backup/personality_dataset.csv"
    
    # What we are predicting, suka.
    TARGET = 'Personality'
    
    # Constants for our little experiments.
    N_FOLDS = 5
    SEED = 42
    N_OPTUNA_TRIALS_ENSEMBLE = 500 # How many times to poke the model with a stick until it gives good weights.
    
    # Cross-validation strategy. Stratified, because our target is imbalanced like my life.
    CV = StratifiedKFold(n_splits=N_FOLDS, random_state=SEED, shuffle=True)
    
    # How we measure success. Simple accuracy. For simple minds.
    METRIC = accuracy_score

# %%
# =====================================================================================
# DATA LOADING & PREPROCESSING, THE DIRTY WORK
# =====================================================================================
# Standard procedure: load train and test.
train_df = pd.read_csv(CFG.TRAIN_PATH, index_col='id')
test_df = pd.read_csv(CFG.TEST_PATH, index_col='id')

# Now for the magic trick. This external data is the key. Some genius found it.
# It contains some of the same samples as train/test, but with... let's say "correct" labels.
original_df = pd.read_csv(CFG.ORIGINAL_PATH)
original_df = original_df.rename(columns={'Personality': 'match_p'}) # Rename to avoid confusion. Call it "matched personality".

# Drop duplicates from original data, because data is always dirty. Always.
original_df = original_df.drop_duplicates([
    'Time_spent_Alone', 'Stage_fear', 'Social_event_attendance', 
    'Going_outside', 'Drained_after_socializing', 'Friends_circle_size', 'Post_frequency'
])

# Merge this holy data into our train/test sets. 'left' join is important.
# If a row from our data is in original_df, it gets a 'match_p' value. If not, it gets NaN.
train_df = train_df.merge(original_df, how='left')
test_df = test_df.merge(original_df, how='left')

# These two columns are categorical, even if they look like numbers. Tell the models, or they will be stupid.
# Fill NaNs with 'missing' string, so model knows it's a special category.
cat_cols = ["Stage_fear", "Drained_after_socializing"]
train_df[cat_cols] = train_df[cat_cols].fillna("missing").astype("category")
test_df[cat_cols] = test_df[cat_cols].fillna("missing").astype("category")

# Map strings to numbers. Because shaitan-machine doesn't understand human language.
# Extrovert -> 0, Introvert -> 1. Remember this, it's important for the submission flip.
train_df[CFG.TARGET] = train_df[CFG.TARGET].map({"Extrovert": 0, "Introvert": 1})
train_df["match_p"] = train_df["match_p"].map({"Extrovert": 0, "Introvert": 1})
test_df["match_p"] = test_df["match_p"].map({"Extrovert": 0, "Introvert": 1})

# Prepare data for models. X is features, y is target. Standard.
X = train_df.drop(CFG.TARGET, axis=1)
y = train_df[CFG.TARGET]
X_test = test_df
_X_test_for_submission = test_df.copy() # Keep a copy for the final submission logic.

# %%
# =====================================================================================
# BASE MODELS TRAINING - THE ARMY OF BOTTLENECKERS
# =====================================================================================
# Here are the hyperparameters. Hardcoded, blyat.
# Found by running Optuna for a week ago. Trust me, they are good.
model_params = {
    "CatBoost": {
        "border_count": 39, "colsample_bylevel": 0.19, "depth": 2, "iterations": 1467,
        "l2_leaf_reg": 31.23, "learning_rate": 0.068, "min_child_samples": 160,
        "random_state": CFG.SEED, "random_strength": 0.85, "scale_pos_weight": 1.16,
        "subsample": 0.31, "verbose": False, "cat_features": cat_cols
    },
    "XGBoost": {
        "colsample_bylevel": 0.81, "colsample_bynode": 0.88, "colsample_bytree": 0.83,
        "gamma": 2.39, "learning_rate": 0.061, "max_depth": 344, "max_leaves": 89,
        "min_child_weight": 10, "n_estimators": 696, "n_jobs": -1, "random_state": CFG.SEED,
        "reg_alpha": 1.84, "reg_lambda": 29.68, "subsample": 0.59, "verbosity": 0, "enable_categorical": True
    },
    "HistGradientBoosting": {
        "l2_regularization": 28.13, "learning_rate": 0.15, "max_depth": 325,
        "max_features": 0.32, "max_iter": 2490, "max_leaf_nodes": 216,
        "min_samples_leaf": 12, "random_state": CFG.SEED, "categorical_features": "from_dtype"
    },
    "LGBM (gbdt)": {
        "boosting_type": "gbdt", "colsample_bytree": 0.64, "learning_rate": 0.065,
        "min_child_samples": 34, "min_child_weight": 0.24, "n_estimators": 498, "n_jobs": -1,
        "num_leaves": 158, "random_state": CFG.SEED, "reg_alpha": 6.56,
        "reg_lambda": 62.66, "subsample": 0.001, "verbose": -1
    },
    "LGBM (goss)": {
        "boosting_type": "goss", "colsample_bytree": 0.83, "learning_rate": 0.07,
        "min_child_samples": 46, "min_child_weight": 0.76, "n_estimators": 1887, "n_jobs": -1,
        "num_leaves": 341, "random_state": CFG.SEED, "reg_alpha": 10.53,
        "reg_lambda": 67.44, "subsample": 0.49, "verbose": -1
    },
    "LGBM (dart)": {
        "boosting_type": "dart", "colsample_bytree": 0.75, "learning_rate": 0.046,
        "min_child_samples": 18, "min_child_weight": 0.47, "n_estimators": 4035, "n_jobs": -1,
        "num_leaves": 393, "random_state": CFG.SEED, "reg_alpha": 48.01,
        "reg_lambda": 89.12, "subsample": 0.016, "verbose": -1
    }
}

# Now, we define the models themselves. A dict of objects, elegant, no?
models_to_train = {
    "CatBoost": CatBoostClassifier(**model_params["CatBoost"]),
    "XGBoost": XGBClassifier(**model_params["XGBoost"]),
    "HistGradientBoosting": HistGradientBoostingClassifier(**model_params["HistGradientBoosting"]),
    "LGBM (gbdt)": LGBMClassifier(**model_params["LGBM (gbdt)"]),
    "LGBM (goss)": LGBMClassifier(**model_params["LGBM (goss)"]),
    "LGBM (dart)": LGBMClassifier(**model_params["LGBM (dart)"]),
}

# Dictionaries to store the crap we get from training.
oof_pred_probs = {}
test_pred_probs = {}
scores = {}

# The great refactored loop! No more copy-paste like salaga programmer.
# We train each model and store its out-of-fold predictions. This is for stacking later.
for name, model in models_to_train.items():
    print(f"===== Training {name} =====")
    trainer = Trainer(
        model,
        cv=CFG.CV,
        metric=CFG.METRIC,
        use_early_stopping=False,
        task="binary",
        metric_precision=6,
    )
    trainer.fit(X, y)
    
    scores[name] = trainer.fold_scores
    oof_pred_probs[name] = trainer.oof_preds
    test_pred_probs[name] = trainer.predict(X_test)

# AutoGluon results are pre-calculated and loaded. Because running it takes forever and Kaggle kernel will die.
# This is like pulling a rabbit out of a hat. A very slow, CPU-intensive rabbit.
oof_pred_probs_files = glob.glob(f'/kaggle/input/s05e07-personality-type-prediction-autogluon/*_oof_pred_probs_*.pkl')
test_pred_probs_files = glob.glob(f'/kaggle/input/s05e07-personality-type-prediction-autogluon/*_test_pred_probs_*.pkl')

if oof_pred_probs_files and test_pred_probs_files:
    print("===== Loading AutoGluon Predictions =====")
    ag_oof_pred_probs = joblib.load(oof_pred_probs_files[0])
    ag_test_pred_probs = joblib.load(test_pred_probs_files[0])
    
    ag_scores = []
    for _, val_idx in CFG.CV.split(X, y):
        y_val = y.iloc[val_idx]
        y_preds = ag_oof_pred_probs[val_idx]
        score = CFG.METRIC(y_val, y_preds >= 0.5)
        ag_scores.append(score)
        
    oof_pred_probs["AutoGluon"] = ag_oof_pred_probs
    test_pred_probs["AutoGluon"] = ag_test_pred_probs
    scores["AutoGluon"] = ag_scores
else:
    print("===== AutoGluon Predictions Not Found =====")
# Out:
# ===== Training CatBoost =====
# Training CatBoostClassifier
#
# --- Fold 0 - accuracy_score: 0.972740 - Time: 10.26 s
# --- Fold 1 - accuracy_score: 0.969231 - Time: 10.08 s
# --- Fold 2 - accuracy_score: 0.968961 - Time: 11.41 s
# --- Fold 3 - accuracy_score: 0.971930 - Time: 10.35 s
# --- Fold 4 - accuracy_score: 0.973542 - Time: 10.39 s
#
# ------ Overall accuracy_score: 0.971281 - Mean accuracy_score: 0.971281 ± 0.001857 - Time: 53.30 s
# ===== Training XGBoost =====
# Training XGBClassifier
#
# --- Fold 0 - accuracy_score: 0.969771 - Time: 0.49 s
# --- Fold 1 - accuracy_score: 0.968151 - Time: 0.44 s
# --- Fold 2 - accuracy_score: 0.966262 - Time: 0.45 s
# --- Fold 3 - accuracy_score: 0.971120 - Time: 2.17 s
# --- Fold 4 - accuracy_score: 0.970842 - Time: 0.42 s
#
# ------ Overall accuracy_score: 0.969229 - Mean accuracy_score: 0.969229 ± 0.001813 - Time: 4.75 s
# ===== Training HistGradientBoosting =====
# Training HistGradientBoostingClassifier
#
# --- Fold 0 - accuracy_score: 0.972200 - Time: 0.49 s
# --- Fold 1 - accuracy_score: 0.969501 - Time: 0.54 s
# --- Fold 2 - accuracy_score: 0.967611 - Time: 0.51 s
# --- Fold 3 - accuracy_score: 0.971660 - Time: 0.78 s
# --- Fold 4 - accuracy_score: 0.971922 - Time: 0.61 s
#
# ------ Overall accuracy_score: 0.970579 - Mean accuracy_score: 0.970579 ± 0.001765 - Time: 3.70 s
# ===== Training LGBM (gbdt) =====
# Training LGBMClassifier
#
# --- Fold 0 - accuracy_score: 0.972200 - Time: 0.50 s
# --- Fold 1 - accuracy_score: 0.969501 - Time: 0.41 s
# --- Fold 2 - accuracy_score: 0.967611 - Time: 0.42 s
# --- Fold 3 - accuracy_score: 0.971660 - Time: 0.46 s
# --- Fold 4 - accuracy_score: 0.972732 - Time: 0.43 s
#
# ------ Overall accuracy_score: 0.970741 - Mean accuracy_score: 0.970741 ± 0.001912 - Time: 3.00 s
# ===== Training LGBM (goss) =====
# Training LGBMClassifier
#
# --- Fold 0 - accuracy_score: 0.970040 - Time: 1.91 s
# --- Fold 1 - accuracy_score: 0.968691 - Time: 1.86 s
# --- Fold 2 - accuracy_score: 0.967881 - Time: 1.79 s
# --- Fold 3 - accuracy_score: 0.970850 - Time: 1.86 s
# --- Fold 4 - accuracy_score: 0.972732 - Time: 2.13 s
#
# ------ Overall accuracy_score: 0.970039 - Mean accuracy_score: 0.970039 ± 0.001696 - Time: 10.40 s
# ===== Training LGBM (dart) =====
# Training LGBMClassifier
#
# --- Fold 0 - accuracy_score: 0.970040 - Time: 67.20 s
# --- Fold 1 - accuracy_score: 0.968421 - Time: 65.43 s
# --- Fold 2 - accuracy_score: 0.966262 - Time: 63.15 s
# --- Fold 3 - accuracy_score: 0.971120 - Time: 66.00 s
# --- Fold 4 - accuracy_score: 0.971112 - Time: 67.20 s
#
# ------ Overall accuracy_score: 0.969391 - Mean accuracy_score: 0.969391 ± 0.001850 - Time: 329.81 s
# ===== AutoGluon Predictions Not Found =====

# %%
# =====================================================================================
# ENSEMBLING - LET'S MIX THIS POTION
# =====================================================================================
# Convert dicts to DataFrames. Easier to work with.
oof_df = pd.DataFrame(oof_pred_probs)
test_df = pd.DataFrame(test_pred_probs)

# --- Method 1: Logistic Regression Stacking ---
# We train a simple model on the predictions of our strong models.
# It learns the best way to combine them. Logit transform helps, makes distribution more normal-like.
print("===== Optimizing Logistic Regression Stacker =====")
X_stack = logit(oof_df.clip(1e-15, 1 - 1e-15))
X_test_stack = logit(test_df.clip(1e-15, 1 - 1e-15))

def lr_objective(trial):
    # This is where Optuna does its magic. Tries different parameters to find the best.
    # It's like watching a blind monkey trying to assemble a clock. Sometimes, it works.
    params = {
        'solver': trial.suggest_categorical('solver', ['liblinear', 'newton-cg', 'lbfgs']),
        'penalty': 'l2',
        'C': trial.suggest_float('C', 0, 1),
        'tol': trial.suggest_float('tol', 1e-6, 1e-2),
        'fit_intercept': trial.suggest_categorical('fit_intercept', [True, False]),
        'class_weight': trial.suggest_categorical('class_weight', ['balanced', None]),
        'random_state': CFG.SEED,
        'max_iter': 1000,
    }
    threshold = trial.suggest_float('threshold', 0.2, 0.8)
    
    trainer = Trainer(
        LogisticRegression(**params), cv=CFG.CV, metric=CFG.METRIC,
        metric_threshold=threshold, use_early_stopping=False, verbose=False, task="binary"
    )
    trainer.fit(X_stack, y)
    return np.mean(trainer.fold_scores)

sampler = optuna.samplers.TPESampler(seed=CFG.SEED)
study_lr = optuna.create_study(direction='maximize', sampler=sampler)
study_lr.optimize(lr_objective, n_trials=100, n_jobs=-1) # 100 trials is enough. We don't have all day.

lr_best_params = study_lr.best_params
lr_threshold = lr_best_params.pop('threshold')
lr_final_model = LogisticRegression(**lr_best_params)
lr_final_model.fit(X_stack, y)
lr_test_preds = lr_final_model.predict_proba(X_test_stack)[:, 1]
scores['LogisticRegression'] = [study_lr.best_value] * CFG.N_FOLDS


# --- Method 2: Weighted Rank Averaging ---
# Simple and powerful, suka. We average ranks, not probabilities. More robust to bullshit.
print("===== Optimizing Weighted Rank Average =====")
oof_rank_df = oof_df.rank(pct=True)
test_rank_df = test_df.rank(pct=True)

def rank_objective(trial):
    weights = {m: trial.suggest_float(m, 0, 1) for m in oof_rank_df.columns}
    total_weight = sum(weights.values())
    
    # Normalize weights to sum to 1. Basic math.
    normalized_weights = {m: w / total_weight for m, w in weights.items()}
    
    # Calculate weighted average of ranks
    preds = np.zeros(len(y))
    for model_name, weight in normalized_weights.items():
        preds += oof_rank_df[model_name] * weight
        
    threshold = trial.suggest_float('threshold', 0.3, 0.7)
    return CFG.METRIC(y, (preds > threshold).astype(int))

sampler = optuna.samplers.TPESampler(seed=CFG.SEED)
study_rank = optuna.create_study(direction='maximize', sampler=sampler)
study_rank.optimize(rank_objective, n_trials=CFG.N_OPTUNA_TRIALS_ENSEMBLE, n_jobs=-1)

rank_best_params = study_rank.best_params
rank_threshold = rank_best_params.pop('threshold')
total_weight = sum(rank_best_params.values())
rank_best_weights = {m: w / total_weight for m, w in rank_best_params.items()}

weighted_rank_preds = np.zeros(len(X_test))
for model_name, weight in rank_best_weights.items():
    weighted_rank_preds += test_rank_df[model_name] * weight
scores['WeightedRank'] = [study_rank.best_value] * CFG.N_FOLDS
# Out:
# [I 2025-07-20 07:55:37,819] A new study created in memory with name: no-name-41ece1ea-88d1-41dd-bee4-38c30ecdb415
# ===== Optimizing Logistic Regression Stacker =====
# [I 2025-07-20 07:55:41,132] Trial 0 finished with value: 0.9700389993092051 and parameters: {'solver': 'newton-cg', 'C': 0.3736793685098255, 'tol': 0.008355968853821985, 'fit_intercept': False, 'class_weight': None, 'threshold': 0.7227716079271518}. Best is trial 0 with value: 0.9700389993092051.
# [I 2025-07-20 07:55:41,146] Trial 3 finished with value: 0.9708487887770598 and parameters: {'solver': 'newton-cg', 'C': 0.2484252030615981, 'tol': 0.0038450215125907117, 'fit_intercept': False, 'class_weight': None, 'threshold': 0.2434448767344299}. Best is trial 3 with value: 0.9708487887770598.
# [I 2025-07-20 07:55:41,430] Trial 2 finished with value: 0.9708487887770598 and parameters: {'solver': 'lbfgs', 'C': 0.35058307284569823, 'tol': 0.0076476233837645, 'fit_intercept': True, 'class_weight': 'balanced', 'threshold': 0.48448315022743327}. Best is trial 3 with value: 0.9708487887770598.
# [I 2025-07-20 07:55:43,524] Trial 6 finished with value: 0.9704169107766925 and parameters: {'solver': 'liblinear', 'C': 0.2108188786918206, 'tol': 0.0005503622701433405, 'fit_intercept': False, 'class_weight': None, 'threshold': 0.22202663743813816}. Best is trial 3 with value: 0.9708487887770598.
# [I 2025-07-20 07:55:44,158] Trial 1 finished with value: 0.9691212476281249 and parameters: {'solver': 'newton-cg', 'C': 0.527115871149117, 'tol': 0.002082624055828176, 'fit_intercept': True, 'class_weight': 'balanced', 'threshold': 0.3271387852484768}. Best is trial 3 with value: 0.9708487887770598.
# [I 2025-07-20 07:55:45,310] Trial 5 finished with value: 0.9709567364165522 and parameters: {'solver': 'newton-cg', 'C': 0.7678994385386309, 'tol': 0.0008645134856765456, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.36930435593519406}. Best is trial 5 with value: 0.9709567364165522.
# [I 2025-07-20 07:55:47,012] Trial 7 finished with value: 0.9704168524817609 and parameters: {'solver': 'newton-cg', 'C': 0.5309564555940135, 'tol': 0.006544241130065911, 'fit_intercept': False, 'class_weight': None, 'threshold': 0.6663772399020105}. Best is trial 5 with value: 0.9709567364165522.
# [I 2025-07-20 07:55:47,022] Trial 4 finished with value: 0.9651264417065258 and parameters: {'solver': 'newton-cg', 'C': 0.2640359796713694, 'tol': 0.003485847046232044, 'fit_intercept': True, 'class_weight': 'balanced', 'threshold': 0.20905202148001778}. Best is trial 5 with value: 0.9709567364165522.
# [I 2025-07-20 07:55:47,856] Trial 9 finished with value: 0.9707947348017827 and parameters: {'solver': 'liblinear', 'C': 0.92148504825857, 'tol': 0.005703995672039117, 'fit_intercept': False, 'class_weight': 'balanced', 'threshold': 0.6849826880275656}. Best is trial 5 with value: 0.9709567364165522.
# [I 2025-07-20 07:55:48,760] Trial 8 finished with value: 0.9710107466706308 and parameters: {'solver': 'lbfgs', 'C': 0.6168416657069189, 'tol': 0.0048992014463191515, 'fit_intercept': True, 'class_weight': 'balanced', 'threshold': 0.5058275234130116}. Best is trial 8 with value: 0.9710107466706308.
# [I 2025-07-20 07:55:50,182] Trial 12 finished with value: 0.9705788103753319 and parameters: {'solver': 'liblinear', 'C': 0.3152234027456863, 'tol': 0.005956529830920941, 'fit_intercept': False, 'class_weight': None, 'threshold': 0.4787420217721538}. Best is trial 8 with value: 0.9710107466706308.
# [I 2025-07-20 07:55:50,868] Trial 11 finished with value: 0.9700389993092051 and parameters: {'solver': 'lbfgs', 'C': 0.5647923709755587, 'tol': 0.008808196367256394, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.46376396649665225}. Best is trial 8 with value: 0.9710107466706308.
# [I 2025-07-20 07:55:51,799] Trial 10 finished with value: 0.9709027115887409 and parameters: {'solver': 'lbfgs', 'C': 0.8949345516846878, 'tol': 0.008937271511831773, 'fit_intercept': False, 'class_weight': 'balanced', 'threshold': 0.5967142663417089}. Best is trial 8 with value: 0.9710107466706308.
# [I 2025-07-20 07:55:53,760] Trial 13 finished with value: 0.97079482224418 and parameters: {'solver': 'lbfgs', 'C': 0.6861868705617182, 'tol': 0.009571956700296766, 'fit_intercept': True, 'class_weight': 'balanced', 'threshold': 0.5591309276371148}. Best is trial 8 with value: 0.9710107466706308.
# [I 2025-07-20 07:55:54,689] Trial 14 finished with value: 0.9701469615224305 and parameters: {'solver': 'lbfgs', 'C': 0.7738991690725673, 'tol': 0.009798610601582346, 'fit_intercept': True, 'class_weight': 'balanced', 'threshold': 0.397285732271147}. Best is trial 8 with value: 0.9710107466706308.
# [I 2025-07-20 07:55:55,029] Trial 15 finished with value: 0.9696070921613721 and parameters: {'solver': 'lbfgs', 'C': 0.7795950546474595, 'tol': 0.001778157353957573, 'fit_intercept': True, 'class_weight': 'balanced', 'threshold': 0.37015830992027354}. Best is trial 8 with value: 0.9710107466706308.
# [I 2025-07-20 07:55:57,793] Trial 16 finished with value: 0.9697150689483303 and parameters: {'solver': 'lbfgs', 'C': 0.7280814677245107, 'tol': 0.0003201638812557481, 'fit_intercept': True, 'class_weight': 'balanced', 'threshold': 0.36372029340247936}. Best is trial 8 with value: 0.9710107466706308.
# [I 2025-07-20 07:55:58,061] Trial 18 finished with value: 0.9702009863502419 and parameters: {'solver': 'newton-cg', 'C': 0.002798152815553401, 'tol': 0.0006930071526326547, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.3689065386750946}. Best is trial 8 with value: 0.9710107466706308.
# [I 2025-07-20 07:55:58,960] Trial 19 finished with value: 0.9708488033507928 and parameters: {'solver': 'newton-cg', 'C': 0.04829440232580706, 'tol': 0.00427662408730588, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.3060483318693983}. Best is trial 8 with value: 0.9710107466706308.
# [I 2025-07-20 07:56:01,485] Trial 22 finished with value: 0.9693371866283087 and parameters: {'solver': 'liblinear', 'C': 0.6305618820105654, 'tol': 0.0027767970819771418, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.7937586759058688}. Best is trial 8 with value: 0.9710107466706308.
# [I 2025-07-20 07:56:01,961] Trial 17 finished with value: 0.9710647277772434 and parameters: {'solver': 'lbfgs', 'C': 0.7384642583561987, 'tol': 0.00017666820167084023, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.3659338803390847}. Best is trial 17 with value: 0.9710647277772434.
# [I 2025-07-20 07:56:02,226] Trial 20 finished with value: 0.9705788103753319 and parameters: {'solver': 'newton-cg', 'C': 0.015647917339937756, 'tol': 0.004012482313556677, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.5779967661764364}. Best is trial 17 with value: 0.9710647277772434.
# [I 2025-07-20 07:56:02,713] Trial 21 finished with value: 0.9690672810952451 and parameters: {'solver': 'newton-cg', 'C': 0.664946159150584, 'tol': 0.00410313470870438, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.7930952210405992}. Best is trial 17 with value: 0.9710647277772434.
# [I 2025-07-20 07:56:04,992] Trial 23 finished with value: 0.9705248146949863 and parameters: {'solver': 'lbfgs', 'C': 0.8437893037467797, 'tol': 0.0048290720180245, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.5524406798850615}. Best is trial 17 with value: 0.9710647277772434.
# [I 2025-07-20 07:56:06,592] Trial 24 finished with value: 0.9710647132035104 and parameters: {'solver': 'lbfgs', 'C': 0.9960702395489311, 'tol': 0.0017632960612645756, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.4262174667151919}. Best is trial 17 with value: 0.9710647277772434.
# [I 2025-07-20 07:56:07,366] Trial 25 finished with value: 0.9710647132035104 and parameters: {'solver': 'lbfgs', 'C': 0.8348573552590081, 'tol': 0.0014492901525112525, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.4274754935372034}. Best is trial 17 with value: 0.9710647277772434.
# [I 2025-07-20 07:56:08,448] Trial 26 finished with value: 0.9710647132035104 and parameters: {'solver': 'lbfgs', 'C': 0.8447430810356633, 'tol': 0.0014229942501549973, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.43738040538166434}. Best is trial 17 with value: 0.9710647277772434.
# [I 2025-07-20 07:56:10,458] Trial 27 finished with value: 0.9710647132035104 and parameters: {'solver': 'lbfgs', 'C': 0.9841591271476803, 'tol': 0.0013565679775736261, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.4282305079903877}. Best is trial 17 with value: 0.9710647277772434.
# [I 2025-07-20 07:56:11,993] Trial 28 finished with value: 0.9710647132035104 and parameters: {'solver': 'lbfgs', 'C': 0.44079820158442307, 'tol': 0.001552807409464267, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.4320485201477842}. Best is trial 17 with value: 0.9710647277772434.
# [I 2025-07-20 07:56:12,761] Trial 29 finished with value: 0.9710647132035104 and parameters: {'solver': 'lbfgs', 'C': 0.9644405888630497, 'tol': 0.0015921673006292208, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.41084244941950393}. Best is trial 17 with value: 0.9710647277772434.
# [I 2025-07-20 07:56:13,384] Trial 30 finished with value: 0.9710647132035104 and parameters: {'solver': 'lbfgs', 'C': 0.9808441057056658, 'tol': 0.0026996680833477477, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.42749089422276926}. Best is trial 17 with value: 0.9710647277772434.
# [I 2025-07-20 07:56:14,803] Trial 31 finished with value: 0.9711187088838562 and parameters: {'solver': 'lbfgs', 'C': 0.9706566453181312, 'tol': 0.0027224784347651557, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.30177644718074786}. Best is trial 31 with value: 0.9711187088838562.
# [I 2025-07-20 07:56:16,178] Trial 32 finished with value: 0.9710107320968978 and parameters: {'solver': 'lbfgs', 'C': 0.9737903930447644, 'tol': 0.0026195181357440162, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.28020369111489235}. Best is trial 31 with value: 0.9711187088838562.
# [I 2025-07-20 07:56:16,901] Trial 33 finished with value: 0.9710107320968978 and parameters: {'solver': 'lbfgs', 'C': 0.870679157603957, 'tol': 0.002764579257993088, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.2818331242756526}. Best is trial 31 with value: 0.9711187088838562.
# [I 2025-07-20 07:56:17,596] Trial 34 finished with value: 0.9709027698836724 and parameters: {'solver': 'lbfgs', 'C': 0.8450732774107811, 'tol': 0.002573758395742542, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.2749348741510767}. Best is trial 31 with value: 0.9711187088838562.
# [I 2025-07-20 07:56:20,125] Trial 36 finished with value: 0.9710107466706308 and parameters: {'solver': 'lbfgs', 'C': 0.864591847211262, 'tol': 0.0022697059677171845, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.3344671114643082}. Best is trial 31 with value: 0.9711187088838562.
# [I 2025-07-20 07:56:20,638] Trial 37 finished with value: 0.9710647277772434 and parameters: {'solver': 'lbfgs', 'C': 0.8221132195576235, 'tol': 0.0022886377033709895, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.32694867115418735}. Best is trial 31 with value: 0.9711187088838562.
# [I 2025-07-20 07:56:22,655] Trial 35 finished with value: 0.9710647277772434 and parameters: {'solver': 'lbfgs', 'C': 0.877584404680487, 'tol': 4.0734901712942764e-05, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.29662905134996753}. Best is trial 31 with value: 0.9711187088838562.
# [I 2025-07-20 07:56:23,881] Trial 40 finished with value: 0.9704169544978912 and parameters: {'solver': 'lbfgs', 'C': 0.9197591042406584, 'tol': 0.003449706439475995, 'fit_intercept': False, 'class_weight': None, 'threshold': 0.3239208031627266}. Best is trial 31 with value: 0.9711187088838562.
# [I 2025-07-20 07:56:24,315] Trial 38 finished with value: 0.9710647277772434 and parameters: {'solver': 'lbfgs', 'C': 0.9062791142792477, 'tol': 0.00026818420648902215, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.3241742029502868}. Best is trial 31 with value: 0.9711187088838562.
# [I 2025-07-20 07:56:25,257] Trial 41 finished with value: 0.9707408119901014 and parameters: {'solver': 'liblinear', 'C': 0.9240256604381838, 'tol': 0.00018907612996994978, 'fit_intercept': False, 'class_weight': None, 'threshold': 0.23998696798780672}. Best is trial 31 with value: 0.9711187088838562.
# [I 2025-07-20 07:56:27,122] Trial 43 finished with value: 0.970632864350609 and parameters: {'solver': 'liblinear', 'C': 0.7162045445615228, 'tol': 0.0010204581676162103, 'fit_intercept': False, 'class_weight': None, 'threshold': 0.23301834799494126}. Best is trial 31 with value: 0.9711187088838562.
# [I 2025-07-20 07:56:27,124] Trial 42 finished with value: 0.9709027553099396 and parameters: {'solver': 'liblinear', 'C': 0.7316213637685175, 'tol': 4.016324898740052e-05, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.24639042692567092}. Best is trial 31 with value: 0.9711187088838562.
# [I 2025-07-20 07:56:28,679] Trial 39 finished with value: 0.9710646549085791 and parameters: {'solver': 'lbfgs', 'C': 0.9365936899129541, 'tol': 0.0001429869250801053, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.523928457323078}. Best is trial 31 with value: 0.9711187088838562.
# [I 2025-07-20 07:56:30,798] Trial 44 finished with value: 0.9701469469486975 and parameters: {'solver': 'lbfgs', 'C': 0.7918475090621204, 'tol': 0.0009330687871066366, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.20347757410815775}. Best is trial 31 with value: 0.9711187088838562.
# [I 2025-07-20 07:56:31,748] Trial 46 finished with value: 0.9710107466706308 and parameters: {'solver': 'lbfgs', 'C': 0.7909652420770737, 'tol': 0.0007745573035991039, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.3261206301987471}. Best is trial 31 with value: 0.9711187088838562.
# [I 2025-07-20 07:56:31,972] Trial 45 finished with value: 0.9701469469486975 and parameters: {'solver': 'lbfgs', 'C': 0.7998353883205837, 'tol': 0.0008029845718916835, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.2041294015524171}. Best is trial 31 with value: 0.9711187088838562.
# [I 2025-07-20 07:56:33,894] Trial 47 finished with value: 0.9701469469486975 and parameters: {'solver': 'lbfgs', 'C': 0.7962912825136932, 'tol': 0.0007971674018724314, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.20349542186733632}. Best is trial 31 with value: 0.9711187088838562.
# [I 2025-07-20 07:56:35,356] Trial 50 finished with value: 0.9689593334557527 and parameters: {'solver': 'lbfgs', 'C': 0.8988252998966101, 'tol': 0.007639475700451728, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.29485180443567527}. Best is trial 31 with value: 0.9711187088838562.
# [I 2025-07-20 07:56:35,876] Trial 49 finished with value: 0.9711187088838562 and parameters: {'solver': 'lbfgs', 'C': 0.8974011096849851, 'tol': 0.0032509385919297987, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.2954906559788488}. Best is trial 31 with value: 0.9711187088838562.
# [I 2025-07-20 07:56:37,458] Trial 48 finished with value: 0.9710107466706308 and parameters: {'solver': 'lbfgs', 'C': 0.8105374221608241, 'tol': 0.0006121651979358409, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.3417344884224123}. Best is trial 31 with value: 0.9711187088838562.
# [I 2025-07-20 07:56:37,993] Trial 51 finished with value: 0.9693371720545759 and parameters: {'solver': 'lbfgs', 'C': 0.5697286120441024, 'tol': 0.003410529803218011, 'fit_intercept': True, 'class_weight': 'balanced', 'threshold': 0.34679319712963497}. Best is trial 31 with value: 0.9711187088838562.
# [I 2025-07-20 07:56:39,123] Trial 52 finished with value: 0.9673397399463104 and parameters: {'solver': 'lbfgs', 'C': 0.4391237278766112, 'tol': 0.003188335808607644, 'fit_intercept': True, 'class_weight': 'balanced', 'threshold': 0.2532885492326456}. Best is trial 31 with value: 0.9711187088838562.
# [I 2025-07-20 07:56:41,755] Trial 53 finished with value: 0.969715098095796 and parameters: {'solver': 'lbfgs', 'C': 0.5629196239959884, 'tol': 0.003350622264818857, 'fit_intercept': False, 'class_weight': 'balanced', 'threshold': 0.263884100060631}. Best is trial 31 with value: 0.9711187088838562.
# [I 2025-07-20 07:56:42,528] Trial 54 finished with value: 0.967555678946494 and parameters: {'solver': 'lbfgs', 'C': 0.8937142399170909, 'tol': 0.002099547645806595, 'fit_intercept': True, 'class_weight': 'balanced', 'threshold': 0.26126354381513484}. Best is trial 31 with value: 0.9711187088838562.
# [I 2025-07-20 07:56:43,116] Trial 55 finished with value: 0.9710647277772434 and parameters: {'solver': 'lbfgs', 'C': 0.890602893220678, 'tol': 0.0021190710648723854, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.3085389681906741}. Best is trial 31 with value: 0.9711187088838562.
# [I 2025-07-20 07:56:44,017] Trial 56 finished with value: 0.9710107320968978 and parameters: {'solver': 'lbfgs', 'C': 0.9483800809248554, 'tol': 0.002046067037174477, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.3855744773829678}. Best is trial 31 with value: 0.9711187088838562.
# [I 2025-07-20 07:56:46,192] Trial 57 finished with value: 0.9710107320968978 and parameters: {'solver': 'lbfgs', 'C': 0.8960120740777795, 'tol': 0.0021812168509564842, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.3756880519861787}. Best is trial 31 with value: 0.9711187088838562.
# [I 2025-07-20 07:56:46,627] Trial 58 finished with value: 0.9710107320968978 and parameters: {'solver': 'lbfgs', 'C': 0.8864765316874403, 'tol': 0.0020883757272673435, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.3866332201019193}. Best is trial 31 with value: 0.9711187088838562.
# [I 2025-07-20 07:56:47,585] Trial 59 finished with value: 0.9707408119901016 and parameters: {'solver': 'newton-cg', 'C': 0.9421629968083631, 'tol': 0.004363018298730401, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.384759146509372}. Best is trial 31 with value: 0.9711187088838562.
# [I 2025-07-20 07:56:48,368] Trial 60 finished with value: 0.9710107466706308 and parameters: {'solver': 'newton-cg', 'C': 0.6839057085099571, 'tol': 0.005392739899332734, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.3014627681156263}. Best is trial 31 with value: 0.9711187088838562.
# [I 2025-07-20 07:56:50,332] Trial 61 finished with value: 0.9710647277772434 and parameters: {'solver': 'newton-cg', 'C': 0.7594566042588623, 'tol': 0.004493549278694023, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.30408444169083976}. Best is trial 31 with value: 0.9711187088838562.
# [I 2025-07-20 07:56:50,769] Trial 62 finished with value: 0.9710647277772434 and parameters: {'solver': 'newton-cg', 'C': 0.737811641852592, 'tol': 0.004403205795900814, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.30342913643043173}. Best is trial 31 with value: 0.9711187088838562.
# [I 2025-07-20 07:56:51,242] Trial 63 finished with value: 0.9709027844574054 and parameters: {'solver': 'newton-cg', 'C': 0.1525294222288447, 'tol': 0.005424615702211094, 'fit_intercept': False, 'class_weight': None, 'threshold': 0.3055063641426012}. Best is trial 31 with value: 0.9711187088838562.
# [I 2025-07-20 07:56:52,442] Trial 64 finished with value: 0.9710107466706308 and parameters: {'solver': 'lbfgs', 'C': 0.7494747682324904, 'tol': 0.003032688851873323, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.35206138520930347}. Best is trial 31 with value: 0.9711187088838562.
# [I 2025-07-20 07:56:55,519] Trial 67 finished with value: 0.970470935604504 and parameters: {'solver': 'lbfgs', 'C': 0.8302463169374732, 'tol': 0.003690769990612066, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.3524218620281175}. Best is trial 31 with value: 0.9711187088838562.
# [I 2025-07-20 07:56:55,524] Trial 65 finished with value: 0.9710107466706308 and parameters: {'solver': 'lbfgs', 'C': 0.8317807781093212, 'tol': 0.0011754016640191816, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.3550352213426361}. Best is trial 31 with value: 0.9711187088838562.
# [I 2025-07-20 07:56:56,302] Trial 68 finished with value: 0.9705249167111166 and parameters: {'solver': 'lbfgs', 'C': 0.8310285971075935, 'tol': 0.0037335010660582988, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.3208896312068324}. Best is trial 31 with value: 0.9711187088838562.
# [I 2025-07-20 07:56:56,514] Trial 66 finished with value: 0.970956765564018 and parameters: {'solver': 'lbfgs', 'C': 0.8286550237000011, 'tol': 0.0011268379809199604, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.35413979325387723}. Best is trial 31 with value: 0.9711187088838562.
# [I 2025-07-20 07:57:00,518] Trial 70 finished with value: 0.9711726899904688 and parameters: {'solver': 'lbfgs', 'C': 0.8655675346720253, 'tol': 0.0004278831270952735, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.32609628895229015}. Best is trial 70 with value: 0.9711726899904688.
# [I 2025-07-20 07:57:01,049] Trial 69 finished with value: 0.9711726899904688 and parameters: {'solver': 'lbfgs', 'C': 0.9935477451411427, 'tol': 0.0004465842272662111, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.3219513064716928}. Best is trial 70 with value: 0.9711726899904688.
# [I 2025-07-20 07:57:01,249] Trial 72 finished with value: 0.9706328497768762 and parameters: {'solver': 'lbfgs', 'C': 0.8708912310569918, 'tol': 0.0005377846841167385, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.22632142949168704}. Best is trial 70 with value: 0.9711726899904688.
# [I 2025-07-20 07:57:01,929] Trial 71 finished with value: 0.9709566926953537 and parameters: {'solver': 'lbfgs', 'C': 0.8627032042507826, 'tol': 0.0004213837236455789, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.6320410168879939}. Best is trial 70 with value: 0.9711726899904688.
# [I 2025-07-20 07:57:05,752] Trial 73 finished with value: 0.9710106592282335 and parameters: {'solver': 'lbfgs', 'C': 0.9985966561224824, 'tol': 0.00042948807689913843, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.6127669757213512}. Best is trial 70 with value: 0.9711726899904688.
# [I 2025-07-20 07:57:06,045] Trial 74 finished with value: 0.9709566926953537 and parameters: {'solver': 'lbfgs', 'C': 0.9635847744433561, 'tol': 0.0003398213566998423, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.6436031443572374}. Best is trial 70 with value: 0.9711726899904688.
# [I 2025-07-20 07:57:06,253] Trial 75 finished with value: 0.9710647277772434 and parameters: {'solver': 'lbfgs', 'C': 0.9896810774732225, 'tol': 0.00039960543176425145, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.2836889640856953}. Best is trial 70 with value: 0.9711726899904688.
# [I 2025-07-20 07:57:08,010] Trial 76 finished with value: 0.9710647277772434 and parameters: {'solver': 'lbfgs', 'C': 0.9612999933166297, 'tol': 0.00032302011802218895, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.2800785341446364}. Best is trial 70 with value: 0.9711726899904688.
# [I 2025-07-20 07:57:09,549] Trial 79 finished with value: 0.9710647277772434 and parameters: {'solver': 'liblinear', 'C': 0.9216698075036639, 'tol': 0.00011260286903394802, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.3242852369182758}. Best is trial 70 with value: 0.9711726899904688.
# [I 2025-07-20 07:57:09,561] Trial 78 finished with value: 0.9710107175231648 and parameters: {'solver': 'liblinear', 'C': 0.9202759109144377, 'tol': 5.80960758458098e-05, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.40833363600656736}. Best is trial 70 with value: 0.9711726899904688.
# [I 2025-07-20 07:57:11,019] Trial 80 finished with value: 0.9709567509902852 and parameters: {'solver': 'liblinear', 'C': 0.9183292862492173, 'tol': 0.001818793221239524, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.40349594014066176}. Best is trial 70 with value: 0.9711726899904688.
# [I 2025-07-20 07:57:14,703] Trial 81 finished with value: 0.9711186651626573 and parameters: {'solver': 'lbfgs', 'C': 0.7019382017592558, 'tol': 0.0012527549596763085, 'fit_intercept': False, 'class_weight': None, 'threshold': 0.4712682455267453}. Best is trial 70 with value: 0.9711726899904688.
# [I 2025-07-20 07:57:14,725] Trial 82 finished with value: 0.9710107175231648 and parameters: {'solver': 'lbfgs', 'C': 0.941787197447144, 'tol': 0.0018275948187259862, 'fit_intercept': False, 'class_weight': None, 'threshold': 0.4499775192449934}. Best is trial 70 with value: 0.9711726899904688.
# [I 2025-07-20 07:57:15,910] Trial 83 finished with value: 0.9711187088838562 and parameters: {'solver': 'lbfgs', 'C': 0.9470652602165968, 'tol': 0.0013468594919655453, 'fit_intercept': False, 'class_weight': None, 'threshold': 0.332225490989564}. Best is trial 70 with value: 0.9711726899904688.
# [I 2025-07-20 07:57:16,650] Trial 77 finished with value: 0.9710107175231648 and parameters: {'solver': 'lbfgs', 'C': 0.967573668914227, 'tol': 3.1585965530118955e-05, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.40614123704739935}. Best is trial 70 with value: 0.9711726899904688.
# [I 2025-07-20 07:57:18,760] Trial 84 finished with value: 0.9711186797363902 and parameters: {'solver': 'lbfgs', 'C': 0.6992683225776564, 'tol': 0.0012772797995243082, 'fit_intercept': False, 'class_weight': None, 'threshold': 0.46624805398572355}. Best is trial 70 with value: 0.9711726899904688.
# [I 2025-07-20 07:57:19,181] Trial 85 finished with value: 0.9710647277772434 and parameters: {'solver': 'lbfgs', 'C': 0.6250946290823639, 'tol': 0.001360707686624134, 'fit_intercept': False, 'class_weight': None, 'threshold': 0.3300682269599795}. Best is trial 70 with value: 0.9711726899904688.
# [I 2025-07-20 07:57:20,435] Trial 86 finished with value: 0.9709567072690864 and parameters: {'solver': 'lbfgs', 'C': 0.6428492381112545, 'tol': 0.0013211819099021578, 'fit_intercept': False, 'class_weight': None, 'threshold': 0.4902014710832811}. Best is trial 70 with value: 0.9711726899904688.
# [I 2025-07-20 07:57:21,097] Trial 87 finished with value: 0.9708487887770598 and parameters: {'solver': 'lbfgs', 'C': 0.7773197361056899, 'tol': 0.0013034489489908564, 'fit_intercept': False, 'class_weight': None, 'threshold': 0.2707283011337503}. Best is trial 70 with value: 0.9711726899904688.
# [I 2025-07-20 07:57:22,550] Trial 88 finished with value: 0.9709567072690864 and parameters: {'solver': 'lbfgs', 'C': 0.6468051322922785, 'tol': 0.001363153529055493, 'fit_intercept': False, 'class_weight': None, 'threshold': 0.49371013404605446}. Best is trial 70 with value: 0.9711726899904688.
# [I 2025-07-20 07:57:24,229] Trial 89 finished with value: 0.9711726316955371 and parameters: {'solver': 'lbfgs', 'C': 0.6537265222907829, 'tol': 0.0007135906564356017, 'fit_intercept': False, 'class_weight': None, 'threshold': 0.5086550367330324}. Best is trial 70 with value: 0.9711726899904688.
# [I 2025-07-20 07:57:25,419] Trial 90 finished with value: 0.9710106883756993 and parameters: {'solver': 'lbfgs', 'C': 0.595671843066617, 'tol': 0.0011003763712590178, 'fit_intercept': False, 'class_weight': None, 'threshold': 0.5143165606959593}. Best is trial 70 with value: 0.9711726899904688.
# [I 2025-07-20 07:57:26,886] Trial 91 finished with value: 0.9709027553099396 and parameters: {'solver': 'lbfgs', 'C': 0.7234365336794104, 'tol': 0.0009819398403845317, 'fit_intercept': False, 'class_weight': 'balanced', 'threshold': 0.5205965686513526}. Best is trial 70 with value: 0.9711726899904688.
# [I 2025-07-20 07:57:27,658] Trial 92 finished with value: 0.9709027553099394 and parameters: {'solver': 'lbfgs', 'C': 0.7071731449615496, 'tol': 0.0009779568650802447, 'fit_intercept': False, 'class_weight': 'balanced', 'threshold': 0.4641499484429423}. Best is trial 70 with value: 0.9711726899904688.
# [I 2025-07-20 07:57:29,558] Trial 93 finished with value: 0.9707408119901014 and parameters: {'solver': 'lbfgs', 'C': 0.5964166352322766, 'tol': 0.000925782425874714, 'fit_intercept': False, 'class_weight': 'balanced', 'threshold': 0.531475599362456}. Best is trial 70 with value: 0.9711726899904688.
# [I 2025-07-20 07:57:30,061] Trial 94 finished with value: 0.971010702949432 and parameters: {'solver': 'lbfgs', 'C': 0.7026476011888195, 'tol': 0.000733623742428287, 'fit_intercept': False, 'class_weight': None, 'threshold': 0.47239993454081786}. Best is trial 70 with value: 0.9711726899904688.
# [I 2025-07-20 07:57:30,587] Trial 95 finished with value: 0.9709027115887409 and parameters: {'solver': 'lbfgs', 'C': 0.7025200600868491, 'tol': 0.0016912284408390134, 'fit_intercept': False, 'class_weight': None, 'threshold': 0.5509047305924171}. Best is trial 70 with value: 0.9711726899904688.
# [I 2025-07-20 07:57:33,372] Trial 96 finished with value: 0.9711186505889244 and parameters: {'solver': 'lbfgs', 'C': 0.5240272429532258, 'tol': 0.000681430021360166, 'fit_intercept': False, 'class_weight': None, 'threshold': 0.5672775909101526}. Best is trial 70 with value: 0.9711726899904688.
# [I 2025-07-20 07:57:33,866] Trial 98 finished with value: 0.9710107175231648 and parameters: {'solver': 'lbfgs', 'C': 0.6689912206579406, 'tol': 0.0016524184468302012, 'fit_intercept': False, 'class_weight': None, 'threshold': 0.44743682736782614}. Best is trial 70 with value: 0.9711726899904688.
# [I 2025-07-20 07:57:34,286] Trial 97 finished with value: 0.971010702949432 and parameters: {'solver': 'lbfgs', 'C': 0.7018686199044004, 'tol': 0.0007325786246502885, 'fit_intercept': False, 'class_weight': None, 'threshold': 0.47222682441682096}. Best is trial 70 with value: 0.9711726899904688.
# [I 2025-07-20 07:57:34,721] Trial 99 finished with value: 0.971010717523165 and parameters: {'solver': 'lbfgs', 'C': 0.47941737985992133, 'tol': 0.0005577065637899464, 'fit_intercept': False, 'class_weight': None, 'threshold': 0.45290645826901027}. Best is trial 70 with value: 0.9711726899904688.
# [I 2025-07-20 07:57:34,912] A new study created in memory with name: no-name-598ae99e-37ba-4e23-af4a-9dfaf0d497f4
# [I 2025-07-20 07:57:34,942] Trial 0 finished with value: 0.7790434031526668 and parameters: {'CatBoost': 0.5535853220571978, 'XGBoost': 0.44798052167639035, 'HistGradientBoosting': 0.38598830663224637, 'LGBM (gbdt)': 0.11565367979307728, 'LGBM (goss)': 0.11356264631621393, 'LGBM (dart)': 0.7520095113955126, 'threshold': 0.5202939890749566}. Best is trial 0 with value: 0.7790434031526668.
# [I 2025-07-20 07:57:34,955] Trial 2 finished with value: 0.8073850140358454 and parameters: {'CatBoost': 0.2831027950227307, 'XGBoost': 0.6658802375505488, 'HistGradientBoosting': 0.5110934910495996, 'LGBM (gbdt)': 0.722096301994298, 'LGBM (goss)': 0.41772224655187795, 'LGBM (dart)': 0.36090683397387924, 'threshold': 0.5522901256308199}. Best is trial 2 with value: 0.8073850140358454.
# [I 2025-07-20 07:57:34,958] Trial 1 finished with value: 0.5779529259339236 and parameters: {'CatBoost': 0.6528024291573302, 'XGBoost': 0.6950974179855299, 'HistGradientBoosting': 0.8576378902918319, 'LGBM (gbdt)': 0.1074010818510458, 'LGBM (goss)': 0.8914095025579974, 'LGBM (dart)': 0.3441703804243743, 'threshold': 0.32700196616853044}. Best is trial 2 with value: 0.8073850140358454.
# [I 2025-07-20 07:57:34,961] Trial 3 finished with value: 0.6018138630965234 and parameters: {'CatBoost': 0.29390137863978216, 'XGBoost': 0.5146071071048309, 'HistGradientBoosting': 0.734561420837054, 'LGBM (gbdt)': 0.6872241918439852, 'LGBM (goss)': 0.6959593009098041, 'LGBM (dart)': 0.2324534849638289, 'threshold': 0.3522469319937378}. Best is trial 2 with value: 0.8073850140358454.
# [I 2025-07-20 07:57:34,983] Trial 5 finished with value: 0.5757395810839991 and parameters: {'CatBoost': 0.5902647273607836, 'XGBoost': 0.45190233610297925, 'HistGradientBoosting': 0.08716647272303424, 'LGBM (gbdt)': 0.6622246606917208, 'LGBM (goss)': 0.41529879532797687, 'LGBM (dart)': 0.4963090754578917, 'threshold': 0.32357508812939895}. Best is trial 2 with value: 0.8073850140358454.
# [I 2025-07-20 07:57:34,974] Trial 4 finished with value: 0.7689483912761822 and parameters: {'CatBoost': 0.3961265567013518, 'XGBoost': 0.7595191249291074, 'HistGradientBoosting': 0.02708927798842875, 'LGBM (gbdt)': 0.36072725484200363, 'LGBM (goss)': 0.05276031301259354, 'LGBM (dart)': 0.14880389882608924, 'threshold': 0.5189495347656358}. Best is trial 2 with value: 0.8073850140358454.
# [I 2025-07-20 07:57:34,992] Trial 6 finished with value: 0.8923558626646513 and parameters: {'CatBoost': 0.09823426287451553, 'XGBoost': 0.9039225352600495, 'HistGradientBoosting': 0.8717147586387646, 'LGBM (gbdt)': 0.387859722371553, 'LGBM (goss)': 0.20061740873591416, 'LGBM (dart)': 0.2533861731338535, 'threshold': 0.6380253637683094}. Best is trial 6 with value: 0.8923558626646513.
# [I 2025-07-20 07:57:35,017] Trial 9 finished with value: 0.8339991362556683 and parameters: {'CatBoost': 0.011238191370198547, 'XGBoost': 0.4138176312839238, 'HistGradientBoosting': 0.8380004582709357, 'LGBM (gbdt)': 0.11277765254254757, 'LGBM (goss)': 0.9229123896668514, 'LGBM (dart)': 0.42726703817799716, 'threshold': 0.5755553493180181}. Best is trial 6 with value: 0.8923558626646513.
# [I 2025-07-20 07:57:35,021] Trial 8 finished with value: 0.8613150507449795 and parameters: {'CatBoost': 0.7112869166542062, 'XGBoost': 0.05449791843259244, 'HistGradientBoosting': 0.5799565098499616, 'LGBM (gbdt)': 0.5745981704263812, 'LGBM (goss)': 0.24037414144163893, 'LGBM (dart)': 0.856579872386726, 'threshold': 0.6003833447380835}. Best is trial 6 with value: 0.8923558626646513.
# [I 2025-07-20 07:57:35,022] Trial 10 finished with value: 0.8395055063701145 and parameters: {'CatBoost': 0.018620544535996486, 'XGBoost': 0.4269002338862755, 'HistGradientBoosting': 0.3273388001979587, 'LGBM (gbdt)': 0.38977342620943756, 'LGBM (goss)': 0.7724305568964114, 'LGBM (dart)': 0.2913853109547401, 'threshold': 0.5850937328383836}. Best is trial 6 with value: 0.8923558626646513.
# [I 2025-07-20 07:57:35,031] Trial 7 finished with value: 0.7499460159792701 and parameters: {'CatBoost': 0.4595228196708204, 'XGBoost': 0.9101812290307172, 'HistGradientBoosting': 0.25955423289775237, 'LGBM (gbdt)': 0.3751094753191695, 'LGBM (goss)': 0.8742564749250086, 'LGBM (dart)': 0.6678999405878686, 'threshold': 0.49657994157443147}. Best is trial 6 with value: 0.8923558626646513.
# ===== Optimizing Weighted Rank Average =====
# [I 2025-07-20 07:57:35,174] Trial 11 finished with value: 0.9432088101921832 and parameters: {'CatBoost': 0.9451669394452821, 'XGBoost': 0.9981860023906008, 'HistGradientBoosting': 0.9704075658557435, 'LGBM (gbdt)': 0.9669285529679198, 'LGBM (goss)': 0.2625821907366134, 'LGBM (dart)': 0.054829891504378225, 'threshold': 0.6981633195172547}. Best is trial 11 with value: 0.9432088101921832.
# [I 2025-07-20 07:57:35,252] Trial 14 finished with value: 0.9311163895486936 and parameters: {'CatBoost': 0.9634828260464315, 'XGBoost': 0.05967969457433342, 'HistGradientBoosting': 0.646776247001371, 'LGBM (gbdt)': 0.9758964426775751, 'LGBM (goss)': 0.2504047976684615, 'LGBM (dart)': 0.8780750903788275, 'threshold': 0.6795809321417275}. Best is trial 11 with value: 0.9432088101921832.
# [I 2025-07-20 07:57:35,286] Trial 12 finished with value: 0.9450982509177284 and parameters: {'CatBoost': 0.9307397844404314, 'XGBoost': 0.05002289872270593, 'HistGradientBoosting': 0.6033567196234045, 'LGBM (gbdt)': 0.931107870991893, 'LGBM (goss)': 0.23915205314968346, 'LGBM (dart)': 0.9997190233848183, 'threshold': 0.6985465859617362}. Best is trial 12 with value: 0.9450982509177284.
# [I 2025-07-20 07:57:35,307] Trial 13 finished with value: 0.9274994601597927 and parameters: {'CatBoost': 0.9765268107525187, 'XGBoost': 0.028748589971247317, 'HistGradientBoosting': 0.6489581520128299, 'LGBM (gbdt)': 0.9556475346622831, 'LGBM (goss)': 0.24803490766323988, 'LGBM (dart)': 0.9590913676785027, 'threshold': 0.6749282294815737}. Best is trial 12 with value: 0.9450982509177284.
# [I 2025-07-20 07:57:35,309] Trial 15 finished with value: 0.9425070179226949 and parameters: {'CatBoost': 0.9808902158708059, 'XGBoost': 0.9855007176265773, 'HistGradientBoosting': 0.9829869239529584, 'LGBM (gbdt)': 0.9630900815963396, 'LGBM (goss)': 0.24718479287809803, 'LGBM (dart)': 0.006767402496404729, 'threshold': 0.6975187412835923}. Best is trial 12 with value: 0.9450982509177284.
# [I 2025-07-20 07:57:35,396] Trial 16 finished with value: 0.9398618009069315 and parameters: {'CatBoost': 0.9817071799594589, 'XGBoost': 0.007734649991162024, 'HistGradientBoosting': 0.6710179493130581, 'LGBM (gbdt)': 0.9774868385469231, 'LGBM (goss)': 0.28233535822604494, 'LGBM (dart)': 0.0383078057642956, 'threshold': 0.6963218924547416}. Best is trial 12 with value: 0.9450982509177284.
# [I 2025-07-20 07:57:35,497] Trial 19 finished with value: 0.6923990498812351 and parameters: {'CatBoost': 0.809554850276393, 'XGBoost': 0.2294279481309801, 'HistGradientBoosting': 0.9484290026004512, 'LGBM (gbdt)': 0.8320271936172747, 'LGBM (goss)': 0.5529010369389645, 'LGBM (dart)': 0.6208477696455051, 'threshold': 0.4409000126134258}. Best is trial 12 with value: 0.9450982509177284.
# [I 2025-07-20 07:57:35,504] Trial 18 finished with value: 0.8918700064780825 and parameters: {'CatBoost': 0.806139798546073, 'XGBoost': 0.28201371057829855, 'HistGradientBoosting': 0.9974914770040654, 'LGBM (gbdt)': 0.8409799374619952, 'LGBM (goss)': 0.4701620605095545, 'LGBM (dart)': 0.6242540678684605, 'threshold': 0.6365551986484684}. Best is trial 12 with value: 0.9450982509177284.
# [I 2025-07-20 07:57:35,514] Trial 17 finished with value: 0.6888361045130641 and parameters: {'CatBoost': 0.8233563342890136, 'XGBoost': 0.26309236905140454, 'HistGradientBoosting': 0.7445668569465106, 'LGBM (gbdt)': 0.8301593464753726, 'LGBM (goss)': 0.5689831391168337, 'LGBM (dart)': 0.6093053097308964, 'threshold': 0.4370234581849618}. Best is trial 12 with value: 0.9450982509177284.
# [I 2025-07-20 07:57:35,624] Trial 20 finished with value: 0.6759879075793566 and parameters: {'CatBoost': 0.8056714800251165, 'XGBoost': 0.22379301270743057, 'HistGradientBoosting': 0.9996725638241667, 'LGBM (gbdt)': 0.8180110201508053, 'LGBM (goss)': 0.5564566551599345, 'LGBM (dart)': 0.5948939702168226, 'threshold': 0.4251388884528378}. Best is trial 12 with value: 0.9450982509177284.
# [I 2025-07-20 07:57:35,689] Trial 21 finished with value: 0.883718419347873 and parameters: {'CatBoost': 0.8120480471418148, 'XGBoost': 0.25371546465198047, 'HistGradientBoosting': 0.4481990005365497, 'LGBM (gbdt)': 0.8227776121300306, 'LGBM (goss)': 0.5251100856384475, 'LGBM (dart)': 0.536796768341009, 'threshold': 0.6290992088635018}. Best is trial 12 with value: 0.9450982509177284.
# [I 2025-07-20 07:57:35,704] Trial 22 finished with value: 0.8828006909954653 and parameters: {'CatBoost': 0.8725584113068096, 'XGBoost': 0.14716375256867625, 'HistGradientBoosting': 0.4430395099903768, 'LGBM (gbdt)': 0.513112884947159, 'LGBM (goss)': 0.3533793365661041, 'LGBM (dart)': 0.10966988137751052, 'threshold': 0.6327269936572963}. Best is trial 12 with value: 0.9450982509177284.
# [I 2025-07-20 07:57:35,704] Trial 23 finished with value: 0.8905743899805657 and parameters: {'CatBoost': 0.8701453390292672, 'XGBoost': 0.1761922967524181, 'HistGradientBoosting': 0.43508641185170893, 'LGBM (gbdt)': 0.5211356139571118, 'LGBM (goss)': 0.017512275164875635, 'LGBM (dart)': 0.9915911258643645, 'threshold': 0.630894926237635}. Best is trial 12 with value: 0.9450982509177284.
# [I 2025-07-20 07:57:35,816] Trial 24 finished with value: 0.8907363420427553 and parameters: {'CatBoost': 0.8932569873931352, 'XGBoost': 0.9917544685561945, 'HistGradientBoosting': 0.7925857031472198, 'LGBM (gbdt)': 0.9064515470932117, 'LGBM (goss)': 0.0022675409072741015, 'LGBM (dart)': 0.0008572246876988876, 'threshold': 0.64026185804626}. Best is trial 12 with value: 0.9450982509177284.
# [I 2025-07-20 07:57:35,837] Trial 25 finished with value: 0.9097927013603974 and parameters: {'CatBoost': 0.8858339485649016, 'XGBoost': 0.9588990306068602, 'HistGradientBoosting': 0.7869376074471219, 'LGBM (gbdt)': 0.9055968662793258, 'LGBM (goss)': 0.3550459692586189, 'LGBM (dart)': 0.01498295470669051, 'threshold': 0.6609816901389989}. Best is trial 12 with value: 0.9450982509177284.
# [I 2025-07-20 07:57:35,931] Trial 27 finished with value: 0.9211833297343986 and parameters: {'CatBoost': 0.7038081860443831, 'XGBoost': 0.993771941127157, 'HistGradientBoosting': 0.7851270553494556, 'LGBM (gbdt)': 0.9102377449740022, 'LGBM (goss)': 0.1289653341890879, 'LGBM (dart)': 0.010382096552103426, 'threshold': 0.6723980198857188}. Best is trial 12 with value: 0.9450982509177284.
# [I 2025-07-20 07:57:35,986] Trial 26 finished with value: 0.9446123947311595 and parameters: {'CatBoost': 0.686587680563229, 'XGBoost': 0.9991682907929907, 'HistGradientBoosting': 0.782876793317687, 'LGBM (gbdt)': 0.9123594486154561, 'LGBM (goss)': 0.14885128168999828, 'LGBM (dart)': 0.039681862031867965, 'threshold': 0.6995799576836783}. Best is trial 12 with value: 0.9450982509177284.
# [I 2025-07-20 07:57:36,070] Trial 29 finished with value: 0.9422910818397754 and parameters: {'CatBoost': 0.7056273825438184, 'XGBoost': 0.8193309045342103, 'HistGradientBoosting': 0.9178321565863801, 'LGBM (gbdt)': 0.731868758834932, 'LGBM (goss)': 0.13040084768438237, 'LGBM (dart)': 0.11932013607739259, 'threshold': 0.6952667693021387}. Best is trial 12 with value: 0.9450982509177284.
# [I 2025-07-20 07:57:36,096] Trial 28 finished with value: 0.945260202979918 and parameters: {'CatBoost': 0.7132811635636696, 'XGBoost': 0.7782248722001603, 'HistGradientBoosting': 0.9410432868337868, 'LGBM (gbdt)': 0.7434325821744548, 'LGBM (goss)': 0.16310457761187155, 'LGBM (dart)': 0.13839226404658128, 'threshold': 0.698658356769711}. Best is trial 28 with value: 0.945260202979918.
# [I 2025-07-20 07:57:36,102] Trial 30 finished with value: 0.9445044266896998 and parameters: {'CatBoost': 0.7112406509854698, 'XGBoost': 0.8196977636766218, 'HistGradientBoosting': 0.9214114473440926, 'LGBM (gbdt)': 0.7241839590310157, 'LGBM (goss)': 0.14213716904896667, 'LGBM (dart)': 0.1663176429658687, 'threshold': 0.6978559416192189}. Best is trial 28 with value: 0.945260202979918.
# [I 2025-07-20 07:57:36,238] Trial 31 finished with value: 0.9427229540056143 and parameters: {'CatBoost': 0.7146712014477188, 'XGBoost': 0.762431330779835, 'HistGradientBoosting': 0.8805981746673204, 'LGBM (gbdt)': 0.7573516894413599, 'LGBM (goss)': 0.14755430393747604, 'LGBM (dart)': 0.16580726487613473, 'threshold': 0.6957348960060883}. Best is trial 28 with value: 0.945260202979918.
# [I 2025-07-20 07:57:36,290] Trial 32 finished with value: 0.8604513064133017 and parameters: {'CatBoost': 0.5552410997071067, 'XGBoost': 0.5772768626234015, 'HistGradientBoosting': 0.5543723765448372, 'LGBM (gbdt)': 0.22574806719040885, 'LGBM (goss)': 0.1599658272988083, 'LGBM (dart)': 0.7385094774370878, 'threshold': 0.6005303307850761}. Best is trial 28 with value: 0.945260202979918.
# [I 2025-07-20 07:57:36,329] Trial 34 finished with value: 0.9158928957028719 and parameters: {'CatBoost': 0.5737957007848721, 'XGBoost': 0.5651866687971113, 'HistGradientBoosting': 0.8830009695690643, 'LGBM (gbdt)': 0.6398607170805635, 'LGBM (goss)': 0.16509073233685823, 'LGBM (dart)': 0.1820490365362462, 'threshold': 0.6641549003225607}. Best is trial 28 with value: 0.945260202979918.
# [I 2025-07-20 07:57:36,332] Trial 33 finished with value: 0.9120060462103218 and parameters: {'CatBoost': 0.5828610965823724, 'XGBoost': 0.6077924894544969, 'HistGradientBoosting': 0.8925315033436222, 'LGBM (gbdt)': 0.6379874198680626, 'LGBM (goss)': 0.16181603702738406, 'LGBM (dart)': 0.19768775461722649, 'threshold': 0.6603558407261726}. Best is trial 28 with value: 0.945260202979918.
# [I 2025-07-20 07:57:36,443] Trial 35 finished with value: 0.9105484776506154 and parameters: {'CatBoost': 0.5950581639220844, 'XGBoost': 0.5810423389998933, 'HistGradientBoosting': 0.5499229928766125, 'LGBM (gbdt)': 0.6089899121942168, 'LGBM (goss)': 0.1807114652239465, 'LGBM (dart)': 0.2078692341902386, 'threshold': 0.6592116505515243}. Best is trial 28 with value: 0.945260202979918.
# [I 2025-07-20 07:57:36,500] Trial 36 finished with value: 0.9110883178579141 and parameters: {'CatBoost': 0.612631925581378, 'XGBoost': 0.8534514616791906, 'HistGradientBoosting': 0.7160104878519448, 'LGBM (gbdt)': 0.645122698365793, 'LGBM (goss)': 0.08702111781706894, 'LGBM (dart)': 0.1979289516596705, 'threshold': 0.6596118606591912}. Best is trial 28 with value: 0.945260202979918.
# [I 2025-07-20 07:57:36,577] Trial 38 finished with value: 0.8681710213776722 and parameters: {'CatBoost': 0.4857891297207416, 'XGBoost': 0.8376841615097101, 'HistGradientBoosting': 0.6951631632444348, 'LGBM (gbdt)': 0.7431837256341914, 'LGBM (goss)': 0.07017149196153388, 'LGBM (dart)': 0.3428541271368135, 'threshold': 0.6129234764488734}. Best is trial 28 with value: 0.945260202979918.
# [I 2025-07-20 07:57:36,580] Trial 37 finished with value: 0.8078168862016843 and parameters: {'CatBoost': 0.6550864348588912, 'XGBoost': 0.8315012651003822, 'HistGradientBoosting': 0.6832451154271064, 'LGBM (gbdt)': 0.7613653223756799, 'LGBM (goss)': 0.07351526464510225, 'LGBM (dart)': 0.35861100973646876, 'threshold': 0.552416536573226}. Best is trial 28 with value: 0.945260202979918.
# [I 2025-07-20 07:57:36,625] Trial 39 finished with value: 0.6173612610667243 and parameters: {'CatBoost': 0.6460782818693961, 'XGBoost': 0.8347395420516049, 'HistGradientBoosting': 0.7048202752191761, 'LGBM (gbdt)': 0.7684766307279708, 'LGBM (goss)': 0.07770993128877288, 'LGBM (dart)': 0.293171979588211, 'threshold': 0.36684641062139867}. Best is trial 28 with value: 0.945260202979918.
# [I 2025-07-20 07:57:36,724] Trial 40 finished with value: 0.6240552796372274 and parameters: {'CatBoost': 0.4612843039554655, 'XGBoost': 0.729969134202131, 'HistGradientBoosting': 0.8337247148724442, 'LGBM (gbdt)': 0.7646582951830578, 'LGBM (goss)': 0.06900773684808517, 'LGBM (dart)': 0.34531808740419573, 'threshold': 0.3732484225992899}. Best is trial 28 with value: 0.945260202979918.
# [I 2025-07-20 07:57:36,826] Trial 41 finished with value: 0.6340963074929821 and parameters: {'CatBoost': 0.3394237062782531, 'XGBoost': 0.6957869095577863, 'HistGradientBoosting': 0.828257840171278, 'LGBM (gbdt)': 0.04014297863979721, 'LGBM (goss)': 0.3723918368162392, 'LGBM (dart)': 0.0744764248644868, 'threshold': 0.385849832883164}. Best is trial 28 with value: 0.945260202979918.
# [I 2025-07-20 07:57:36,827] Trial 43 finished with value: 0.7305117685165191 and parameters: {'CatBoost': 0.753311218980974, 'XGBoost': 0.706813130018241, 'HistGradientBoosting': 0.8293339631127156, 'LGBM (gbdt)': 0.700193998508817, 'LGBM (goss)': 0.3454169059582849, 'LGBM (dart)': 0.09421456962800914, 'threshold': 0.48174780760251257}. Best is trial 28 with value: 0.945260202979918.
# [I 2025-07-20 07:57:36,845] Trial 42 finished with value: 0.8104621032174476 and parameters: {'CatBoost': 0.41079416597635976, 'XGBoost': 0.6733000604315719, 'HistGradientBoosting': 0.8310954123550384, 'LGBM (gbdt)': 0.8728247395769203, 'LGBM (goss)': 0.32904351480474764, 'LGBM (dart)': 0.10129076692240432, 'threshold': 0.5589014289886439}. Best is trial 28 with value: 0.945260202979918.
# [I 2025-07-20 07:57:36,965] Trial 44 finished with value: 0.929766789030447 and parameters: {'CatBoost': 0.7579370255850724, 'XGBoost': 0.9218568372800368, 'HistGradientBoosting': 0.9382853085461248, 'LGBM (gbdt)': 0.9966365400760138, 'LGBM (goss)': 0.32986097262567543, 'LGBM (dart)': 0.06863237133424009, 'threshold': 0.6825268788559102}. Best is trial 28 with value: 0.945260202979918.
# ...
# [I 2025-07-20 07:58:07,726] Trial 460 finished with value: 0.9366767436838696 and parameters: {'CatBoost': 0.4899493361497677, 'XGBoost': 0.23902040721040277, 'HistGradientBoosting': 0.9991755505027897, 'LGBM (gbdt)': 0.05202765942836848, 'LGBM (goss)': 0.08102889745552208, 'LGBM (dart)': 0.8944163762728558, 'threshold': 0.6809221470910484}. Best is trial 418 with value: 0.9496329086590369.
# [I 2025-07-20 07:58:07,908] Trial 461 finished with value: 0.9355430792485424 and parameters: {'CatBoost': 0.4748935649787917, 'XGBoost': 0.1725983875445762, 'HistGradientBoosting': 0.9651881027168123, 'LGBM (gbdt)': 0.057443137714222145, 'LGBM (goss)': 0.04016138584176571, 'LGBM (dart)': 0.8998430650045698, 'threshold': 0.6795672482258142}. Best is trial 418 with value: 0.9496329086590369.
# [I 2025-07-20 07:58:07,965] Trial 462 finished with value: 0.9350572230619737 and parameters: {'CatBoost': 0.4709305351233022, 'XGBoost': 0.20837415659653025, 'HistGradientBoosting': 0.963685845043262, 'LGBM (gbdt)': 0.06539572982239557, 'LGBM (goss)': 0.044258229361068234, 'LGBM (dart)': 0.8770354088863554, 'threshold': 0.6792937140516384}. Best is trial 418 with value: 0.9496329086590369.
# [I 2025-07-20 07:58:08,012] Trial 463 finished with value: 0.9376484560570071 and parameters: {'CatBoost': 0.4960750319977219, 'XGBoost': 0.23835141595095133, 'HistGradientBoosting': 0.9998250537515538, 'LGBM (gbdt)': 0.043420278275641586, 'LGBM (goss)': 0.04797263108867855, 'LGBM (dart)': 0.8572492453757722, 'threshold': 0.6819462781494317}. Best is trial 418 with value: 0.9496329086590369.
# [I 2025-07-20 07:58:08,062] Trial 464 finished with value: 0.9406175771971497 and parameters: {'CatBoost': 0.5633527279561885, 'XGBoost': 0.20716265479365484, 'HistGradientBoosting': 0.9650628615468854, 'LGBM (gbdt)': 0.03108846669946704, 'LGBM (goss)': 0.04243565323436274, 'LGBM (dart)': 0.8632892058704573, 'threshold': 0.6860829336559635}. Best is trial 418 with value: 0.9496329086590369.
# [I 2025-07-20 07:58:08,227] Trial 465 finished with value: 0.9416972576117469 and parameters: {'CatBoost': 0.5586155109381511, 'XGBoost': 0.20829096553161316, 'HistGradientBoosting': 0.9595339895881999, 'LGBM (gbdt)': 0.03432384464930857, 'LGBM (goss)': 0.047565279781335804, 'LGBM (dart)': 0.8551265713560073, 'threshold': 0.6875977779770167}. Best is trial 418 with value: 0.9496329086590369.
# [I 2025-07-20 07:58:08,261] Trial 466 finished with value: 0.9494709565968473 and parameters: {'CatBoost': 0.562391495525217, 'XGBoost': 0.23118373751797813, 'HistGradientBoosting': 0.9489854049940181, 'LGBM (gbdt)': 0.030404579401007648, 'LGBM (goss)': 0.06735045064329302, 'LGBM (dart)': 0.8545875284934721, 'threshold': 0.6999676534275069}. Best is trial 418 with value: 0.9496329086590369.
# [I 2025-07-20 07:58:08,317] Trial 467 finished with value: 0.9436946663787519 and parameters: {'CatBoost': 0.5617408855685426, 'XGBoost': 0.03596507859735087, 'HistGradientBoosting': 0.9459139440328485, 'LGBM (gbdt)': 0.09167971255250915, 'LGBM (goss)': 0.0714208758039181, 'LGBM (dart)': 0.835580775026759, 'threshold': 0.691762822654524}. Best is trial 418 with value: 0.9496329086590369.
# [I 2025-07-20 07:58:08,401] Trial 468 finished with value: 0.9493090045346577 and parameters: {'CatBoost': 0.5606504017835178, 'XGBoost': 0.14000251715602113, 'HistGradientBoosting': 0.9401403062288192, 'LGBM (gbdt)': 0.09632463467837385, 'LGBM (goss)': 0.07385636132472566, 'LGBM (dart)': 0.8288550653202511, 'threshold': 0.699655277662741}. Best is trial 418 with value: 0.9496329086590369.
# [I 2025-07-20 07:58:08,580] Trial 469 finished with value: 0.9495789246383071 and parameters: {'CatBoost': 0.5222106921319274, 'XGBoost': 0.2554122151484413, 'HistGradientBoosting': 0.9538526782681821, 'LGBM (gbdt)': 0.09159993105048711, 'LGBM (goss)': 0.08067261933646719, 'LGBM (dart)': 0.8296984880178756, 'threshold': 0.6998281326954169}. Best is trial 418 with value: 0.9496329086590369.
# [I 2025-07-20 07:58:08,602] Trial 470 finished with value: 0.9494709565968473 and parameters: {'CatBoost': 0.5190653810360517, 'XGBoost': 0.03850961190025804, 'HistGradientBoosting': 0.9316131906740421, 'LGBM (gbdt)': 0.0855156299457824, 'LGBM (goss)': 0.021972059337655142, 'LGBM (dart)': 0.8275960252618296, 'threshold': 0.6998653326950962}. Best is trial 418 with value: 0.9496329086590369.
# [I 2025-07-20 07:58:08,619] Trial 471 finished with value: 0.9442345065860506 and parameters: {'CatBoost': 0.522006243370113, 'XGBoost': 0.231104136930716, 'HistGradientBoosting': 0.9312454003032811, 'LGBM (gbdt)': 5.82156540866359e-05, 'LGBM (goss)': 0.06539267377693081, 'LGBM (dart)': 0.8214382388592498, 'threshold': 0.6926344679760945}. Best is trial 418 with value: 0.9496329086590369.
# [I 2025-07-20 07:58:08,759] Trial 472 finished with value: 0.9444504426689699 and parameters: {'CatBoost': 0.5182724469710756, 'XGBoost': 0.2596403401900264, 'HistGradientBoosting': 0.9399684470062611, 'LGBM (gbdt)': 0.018203076915314826, 'LGBM (goss)': 0.0915878228302179, 'LGBM (dart)': 0.8225828771313828, 'threshold': 0.6929695984655314}. Best is trial 418 with value: 0.9496329086590369.
# [I 2025-07-20 07:58:08,900] Trial 474 finished with value: 0.9430468581299936 and parameters: {'CatBoost': 0.5220812018284573, 'XGBoost': 0.08899928520565713, 'HistGradientBoosting': 0.937037090663351, 'LGBM (gbdt)': 0.08738880464977312, 'LGBM (goss)': 0.009395421113567629, 'LGBM (dart)': 0.8241501832600568, 'threshold': 0.6907423088489619}. Best is trial 418 with value: 0.9496329086590369.
# [I 2025-07-20 07:58:08,953] Trial 473 finished with value: 0.9438566184409415 and parameters: {'CatBoost': 0.5236347388249829, 'XGBoost': 0.1423936626869908, 'HistGradientBoosting': 0.9394147613495534, 'LGBM (gbdt)': 0.08633779843291384, 'LGBM (goss)': 0.020892817706516582, 'LGBM (dart)': 0.8259539904537087, 'threshold': 0.6920965569485726}. Best is trial 418 with value: 0.9496329086590369.
# [I 2025-07-20 07:58:08,988] Trial 475 finished with value: 0.590045346577413 and parameters: {'CatBoost': 0.5032047333808013, 'XGBoost': 0.0819119542209383, 'HistGradientBoosting': 0.9805667599221851, 'LGBM (gbdt)': 0.08718189239457211, 'LGBM (goss)': 0.01819610723626488, 'LGBM (dart)': 0.8341574021294946, 'threshold': 0.33770786390373525}. Best is trial 418 with value: 0.9496329086590369.
# [I 2025-07-20 07:58:09,091] Trial 476 finished with value: 0.9418592096739365 and parameters: {'CatBoost': 0.496009298494139, 'XGBoost': 0.017378988208037602, 'HistGradientBoosting': 0.9789670763637935, 'LGBM (gbdt)': 0.09330542729342657, 'LGBM (goss)': 0.07210961153445761, 'LGBM (dart)': 0.8412019577020594, 'threshold': 0.6880040775901899}. Best is trial 418 with value: 0.9496329086590369.
# [I 2025-07-20 07:58:09,246] Trial 477 finished with value: 0.9287410926365796 and parameters: {'CatBoost': 0.5406844785224193, 'XGBoost': 0.02264324567673275, 'HistGradientBoosting': 0.983980981931378, 'LGBM (gbdt)': 0.08221591387622029, 'LGBM (goss)': 0.026936786416049574, 'LGBM (dart)': 0.841913694440655, 'threshold': 0.6724247372148444}. Best is trial 418 with value: 0.9496329086590369.
# [I 2025-07-20 07:58:09,289] Trial 478 finished with value: 0.9404016411142302 and parameters: {'CatBoost': 0.5042627203760521, 'XGBoost': 0.0662060440634561, 'HistGradientBoosting': 0.9786987670218946, 'LGBM (gbdt)': 0.10719596270448417, 'LGBM (goss)': 0.06079997581099578, 'LGBM (dart)': 0.8421695079705022, 'threshold': 0.6856904764657888}. Best is trial 418 with value: 0.9496329086590369.
# [I 2025-07-20 07:58:09,327] Trial 479 finished with value: 0.9283632044914705 and parameters: {'CatBoost': 0.542073101826752, 'XGBoost': 0.010160647497478692, 'HistGradientBoosting': 0.9820802304141313, 'LGBM (gbdt)': 0.07430863129587204, 'LGBM (goss)': 0.06450498486814563, 'LGBM (dart)': 0.8447826722742922, 'threshold': 0.6720010207823534}. Best is trial 418 with value: 0.9496329086590369.
# [I 2025-07-20 07:58:09,407] Trial 480 finished with value: 0.9263118117037357 and parameters: {'CatBoost': 0.5444052038440614, 'XGBoost': 0.04486308989129337, 'HistGradientBoosting': 0.9178041120277888, 'LGBM (gbdt)': 0.07379807663040694, 'LGBM (goss)': 0.05765196248271674, 'LGBM (dart)': 0.8509520134573391, 'threshold': 0.6694287296709415}. Best is trial 418 with value: 0.9496329086590369.
# [I 2025-07-20 07:58:09,591] Trial 481 finished with value: 0.9409954653422586 and parameters: {'CatBoost': 0.5437931891757269, 'XGBoost': 0.05227852906302752, 'HistGradientBoosting': 0.9179298255218711, 'LGBM (gbdt)': 0.06296648578363685, 'LGBM (goss)': 0.06049443673977527, 'LGBM (dart)': 0.8522451891862045, 'threshold': 0.6865470469906916}. Best is trial 418 with value: 0.9496329086590369.
# [I 2025-07-20 07:58:09,604] Trial 482 finished with value: 0.9494709565968473 and parameters: {'CatBoost': 0.5487464056739162, 'XGBoost': 0.24689884615565627, 'HistGradientBoosting': 0.9245058397425134, 'LGBM (gbdt)': 0.07120546561656785, 'LGBM (goss)': 0.07650040986313231, 'LGBM (dart)': 0.8729388757728024, 'threshold': 0.6999975388349425}. Best is trial 418 with value: 0.9496329086590369.
# [I 2025-07-20 07:58:09,652] Trial 483 finished with value: 0.8527855754696609 and parameters: {'CatBoost': 0.5480905746053539, 'XGBoost': 0.24591824308293336, 'HistGradientBoosting': 0.34805465332677804, 'LGBM (gbdt)': 0.021387036957780728, 'LGBM (goss)': 0.09960760720577418, 'LGBM (dart)': 0.8707548071368851, 'threshold': 0.5907739618054291}. Best is trial 418 with value: 0.9496329086590369.
# [I 2025-07-20 07:58:09,752] Trial 484 finished with value: 0.9495789246383071 and parameters: {'CatBoost': 0.5569523500657041, 'XGBoost': 0.23688461446427245, 'HistGradientBoosting': 0.9997701693047595, 'LGBM (gbdt)': 0.0224243760774338, 'LGBM (goss)': 0.07626796345115383, 'LGBM (dart)': 0.8727651806773332, 'threshold': 0.6998237005227717}. Best is trial 418 with value: 0.9496329086590369.
# [I 2025-07-20 07:58:09,918] Trial 485 finished with value: 0.9492550205139278 and parameters: {'CatBoost': 0.5756474214935615, 'XGBoost': 0.2453540881349219, 'HistGradientBoosting': 0.9989242578895201, 'LGBM (gbdt)': 0.02131654194837433, 'LGBM (goss)': 0.001141203526652243, 'LGBM (dart)': 0.8769305109576221, 'threshold': 0.6994506427876749}. Best is trial 418 with value: 0.9496329086590369.
# [I 2025-07-20 07:58:09,942] Trial 486 finished with value: 0.9390520405959836 and parameters: {'CatBoost': 0.5715137204445456, 'XGBoost': 0.2473094190573022, 'HistGradientBoosting': 0.06899861652115913, 'LGBM (gbdt)': 0.10352965796444509, 'LGBM (goss)': 0.08716396926840411, 'LGBM (dart)': 0.8759395330984504, 'threshold': 0.6941818279289733}. Best is trial 418 with value: 0.9496329086590369.
# [I 2025-07-20 07:58:09,971] Trial 487 finished with value: 0.9446123947311595 and parameters: {'CatBoost': 0.44632771535080484, 'XGBoost': 0.22233977758030057, 'HistGradientBoosting': 0.9596128390523926, 'LGBM (gbdt)': 0.10734946662012562, 'LGBM (goss)': 0.08174420324216869, 'LGBM (dart)': 0.919209605142335, 'threshold': 0.6934152997404501}. Best is trial 418 with value: 0.9496329086590369.
# [I 2025-07-20 07:58:10,059] Trial 488 finished with value: 0.9495789246383071 and parameters: {'CatBoost': 0.5681173597405432, 'XGBoost': 0.22617916595478005, 'HistGradientBoosting': 0.9999912660473527, 'LGBM (gbdt)': 0.04967271462922715, 'LGBM (goss)': 0.08677086239521306, 'LGBM (dart)': 0.8774320598155391, 'threshold': 0.6999370974488713}. Best is trial 418 with value: 0.9496329086590369.
# [I 2025-07-20 07:58:10,227] Trial 489 finished with value: 0.9438566184409415 and parameters: {'CatBoost': 0.5654088092300732, 'XGBoost': 0.2235788323017319, 'HistGradientBoosting': 0.9989530256661799, 'LGBM (gbdt)': 0.04646708407881546, 'LGBM (goss)': 0.02888592407855614, 'LGBM (dart)': 0.9151683475849466, 'threshold': 0.6923599808054396}. Best is trial 418 with value: 0.9496329086590369.
# [I 2025-07-20 07:58:10,274] Trial 490 finished with value: 0.9360829194558411 and parameters: {'CatBoost': 0.5296117819474562, 'XGBoost': 0.22027581587452733, 'HistGradientBoosting': 0.9971040621059256, 'LGBM (gbdt)': 0.0455935681474977, 'LGBM (goss)': 0.02108799190832452, 'LGBM (dart)': 0.8794226301377176, 'threshold': 0.6802145110259188}. Best is trial 418 with value: 0.9496329086590369.
# [I 2025-07-20 07:58:10,311] Trial 491 finished with value: 0.9341934787302958 and parameters: {'CatBoost': 0.5197003305318074, 'XGBoost': 0.2237377710500596, 'HistGradientBoosting': 0.9974481442911253, 'LGBM (gbdt)': 0.046100663782990485, 'LGBM (goss)': 0.0035882094416712796, 'LGBM (dart)': 0.9127983678465729, 'threshold': 0.6784597331094337}. Best is trial 418 with value: 0.9496329086590369.
# [I 2025-07-20 07:58:10,365] Trial 492 finished with value: 0.9375404880155473 and parameters: {'CatBoost': 0.5218345421167013, 'XGBoost': 0.21935166000316106, 'HistGradientBoosting': 0.993595752594411, 'LGBM (gbdt)': 0.05476324179417536, 'LGBM (goss)': 0.024153207308730842, 'LGBM (dart)': 0.907194549508539, 'threshold': 0.6817020975628139}. Best is trial 418 with value: 0.9496329086590369.
# [I 2025-07-20 07:58:10,574] Trial 493 finished with value: 0.9374325199740877 and parameters: {'CatBoost': 0.5301851813638985, 'XGBoost': 0.19697244594017974, 'HistGradientBoosting': 0.9962758758972187, 'LGBM (gbdt)': 0.05952324080042189, 'LGBM (goss)': 0.037897792365124555, 'LGBM (dart)': 0.9002476638549545, 'threshold': 0.6819127666947975}. Best is trial 418 with value: 0.9496329086590369.
# [I 2025-07-20 07:58:10,607] Trial 494 finished with value: 0.9406715612178795 and parameters: {'CatBoost': 0.5547590702356846, 'XGBoost': 0.19975311505449178, 'HistGradientBoosting': 0.9672198394328508, 'LGBM (gbdt)': 0.06322499836013055, 'LGBM (goss)': 0.010904812548485174, 'LGBM (dart)': 0.910790036076135, 'threshold': 0.6860334158265669}. Best is trial 418 with value: 0.9496329086590369.
# [I 2025-07-20 07:58:10,647] Trial 495 finished with value: 0.9403476570935003 and parameters: {'CatBoost': 0.5562067968359704, 'XGBoost': 0.19695826657068805, 'HistGradientBoosting': 0.9680623173514483, 'LGBM (gbdt)': 0.00036817580736275444, 'LGBM (goss)': 0.04105020110090947, 'LGBM (dart)': 0.8767364303281064, 'threshold': 0.6855794510640482}. Best is trial 418 with value: 0.9496329086590369.
# [I 2025-07-20 07:58:10,722] Trial 496 finished with value: 0.9421291297775858 and parameters: {'CatBoost': 0.5578037932212315, 'XGBoost': 0.19200019240211297, 'HistGradientBoosting': 0.9658657327043361, 'LGBM (gbdt)': 0.0011476508846764845, 'LGBM (goss)': 0.04464484918009469, 'LGBM (dart)': 0.8848034294434012, 'threshold': 0.6886281267171206}. Best is trial 418 with value: 0.9496329086590369.
# [I 2025-07-20 07:58:10,847] Trial 497 finished with value: 0.9067695961995249 and parameters: {'CatBoost': 0.554898357541355, 'XGBoost': 0.2725707277549495, 'HistGradientBoosting': 0.9662021110212405, 'LGBM (gbdt)': 0.02202866878720619, 'LGBM (goss)': 0.07788736865174922, 'LGBM (dart)': 0.8746494400461364, 'threshold': 0.6470339722357557}. Best is trial 418 with value: 0.9496329086590369.
# [I 2025-07-20 07:58:10,873] Trial 498 finished with value: 0.9440185705031311 and parameters: {'CatBoost': 0.5814572292797087, 'XGBoost': 0.2721658930016524, 'HistGradientBoosting': 0.9314835089464204, 'LGBM (gbdt)': 0.02156138048792891, 'LGBM (goss)': 0.10862798224477374, 'LGBM (dart)': 0.8756758177279919, 'threshold': 0.6927160517362189}. Best is trial 418 with value: 0.9496329086590369.
# [I 2025-07-20 07:58:10,878] Trial 499 finished with value: 0.9433167782336428 and parameters: {'CatBoost': 0.585896479156902, 'XGBoost': 0.25981133362985864, 'HistGradientBoosting': 0.9275950236436087, 'LGBM (gbdt)': 0.030401389358213148, 'LGBM (goss)': 0.11126880355849209, 'LGBM (dart)': 0.8833469568358461, 'threshold': 0.6919597911409826}. Best is trial 418 with value: 0.9496329086590369.

# %%
# =====================================================================================
# SUBMISSION - THE FINAL JUDGEMENT
# =====================================================================================

# A holy function. It creates the submission file. Do not touch without praying first.
def save_submission(name: str, test_preds: np.ndarray, score: float, threshold: float):
    sub = pd.read_csv(CFG.SAMPLE_SUB_PATH)
    
    # Apply the optimized threshold to get final 0/1 predictions.
    sub[CFG.TARGET] = (test_preds > threshold).astype(int)
    
    # HERE IS THE REAL MAGIC, BLYAT!
    # For rows we found in the original dataset, we OVERWRITE our prediction.
    # The labels are FLIPPED. If original says Extrovert (0), we predict Introvert (1).
    # Why? Because competition data is fucked up. This is Kaggle, junior. Get used to it.
    sub.loc[_X_test_for_submission.match_p == 0, CFG.TARGET] = 1 # Original was Extrovert, we say Introvert.
    sub.loc[_X_test_for_submission.match_p == 1, CFG.TARGET] = 0 # Original was Introvert, we say Extrovert.
    
    # Now map our 0/1 back to strings for the submission file.
    sub[CFG.TARGET] = sub[CFG.TARGET].map({0: "Extrovert", 1: "Introvert"})
    
    # Save the file. The score in filename is our badge of honor.
    filename = f'sub_{name}_{score:.6f}.csv'
    sub.to_csv(filename, index=False)
    print(f"Submission saved to {filename}")
    return sub.head()

# Create submissions for both ensemble methods
print("\n===== Creating Submission Files =====")
save_submission('logistic-regression', lr_test_preds, np.mean(scores['LogisticRegression']), lr_threshold)
save_submission('weighted-rank', weighted_rank_preds, np.mean(scores['WeightedRank']), rank_threshold)
# Out:
# ===== Creating Submission Files =====
# Submission saved to sub_logistic-regression_0.971173.csv
# Submission saved to sub_weighted-rank_0.949633.csv
#       id Personality
# 0  18524   Extrovert
# 1  18525   Introvert
# 2  18526   Extrovert
# 3  18527   Extrovert
# 4  18528   Introvert
