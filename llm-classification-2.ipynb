# %%
import os
import gc
import random

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    AutoConfig,
    get_linear_schedule_with_warmup,
)
from torch.optim import AdamW
from sklearn.model_selection import train_test_split
from sklearn.metrics import log_loss

import torch._dynamo

torch._dynamo.config.suppress_errors = True

# %%
# --- Конфигурац ---
class CFG:
    MODEL_NAME = '/kaggle/input/modernbert/transformers/base/1/modernbert-base'
    MAX_LENGTH = 1024
    BATCH_SIZE = 8
    EPOCHS = 2  
    LEARNING_RATE = 2e-5
    WEIGHT_DECAY = 0.01
    WARMUP_RATIO = 0.1
    NUM_CLASSES = 3
    DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    SEED = 42
    TRAIN_FILE = '/kaggle/input/llm-classification-finetuning/train.csv'
    TEST_FILE = '/kaggle/input/llm-classification-finetuning/test.csv'
    SAMPLE_SUBMISSION = '/kaggle/input/llm-classification-finetuning/sample_submission.csv'
    OUTPUT_DIR = '/kaggle/working/'
    USE_FULL_DATA = True
    
# --- Установка SEED для воспроизводимости ---
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seed_everything(CFG.SEED)

# %%
# --- Загрузка и предобработка данных ---
train_df = pd.read_csv(CFG.TRAIN_FILE)
test_df = pd.read_csv(CFG.TEST_FILE)
sample_submission_df = pd.read_csv(CFG.SAMPLE_SUBMISSION)

# Отображение классов в числа
label_mapping = {'winner_model_a': 0, 'winner_model_b': 1, 'winner_tie': 2}
train_df['label_encoded'] = train_df['winner_model_a'].astype(int) * 0 + \
                            train_df['winner_model_b'].astype(int) * 1 + \
                            train_df['winner_tie'].astype(int) * 2

# %%
# Для быстрой отладки можно использовать часть данных
if not CFG.USE_FULL_DATA:
    train_df = train_df.sample(n=1000, random_state=CFG.SEED).reset_index(drop=True)

# --- Токенизатор ---
tokenizer = AutoTokenizer.from_pretrained(CFG.MODEL_NAME)

# %%
# --- Создание Dataset ---
class LLMPreferenceDataset(Dataset):
    def __init__(self, df, tokenizer, max_length, is_test=False):
        self.df = df
        self.tokenizer = tokenizer
        self.max_length = max_length
        self.is_test = is_test
        self.prompts = df['prompt'].values
        self.responses_a = df['response_a'].values
        self.responses_b = df['response_b'].values
        if not self.is_test:
            self.labels = df['label_encoded'].values
        self.ids = df['id'].values

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        prompt = str(self.prompts[idx])
        response_a = str(self.responses_a[idx])
        response_b = str(self.responses_b[idx])

        # Формируем входной текст: "PROMPT [SEP] RESPONSE_A [SEP] RESPONSE_B"
        text = f"{prompt}{self.tokenizer.sep_token}{response_a}{self.tokenizer.sep_token}{response_b}"

        inputs = self.tokenizer.encode_plus(
            text,
            add_special_tokens=True, # Добавляет [CLS] и [SEP]
            max_length=self.max_length,
            padding='max_length',
            truncation=True,
            return_attention_mask=True,
            return_tensors='pt'
        )

        item = {
            'input_ids': inputs['input_ids'].squeeze(0),
            'attention_mask': inputs['attention_mask'].squeeze(0)
        }
        
        current_id = self.ids[idx] # Сохраняем ID

        if not self.is_test:
            item['labels'] = torch.tensor(self.labels[idx], dtype=torch.long)
            return item
        else:
            # Для тестового набора данных возвращаем и ID
            return item, current_id

# %%
# --- Разделение на обучающую и валидационную выборки ---
train_texts, val_texts, train_labels, val_labels = train_test_split(
    train_df[['id','prompt', 'response_a', 'response_b']],
    train_df['label_encoded'],
    test_size=0.2,
    random_state=CFG.SEED,
    stratify=train_df['label_encoded']
)

train_split_df = pd.DataFrame({
    'id': train_texts['id'],
    'prompt': train_texts['prompt'],
    'response_a': train_texts['response_a'],
    'response_b': train_texts['response_b'],
    'label_encoded': train_labels
})

val_split_df = pd.DataFrame({
    'id': val_texts['id'],
    'prompt': val_texts['prompt'],
    'response_a': val_texts['response_a'],
    'response_b': val_texts['response_b'],
    'label_encoded': val_labels
})


train_dataset = LLMPreferenceDataset(train_split_df, tokenizer, CFG.MAX_LENGTH)
val_dataset = LLMPreferenceDataset(val_split_df, tokenizer, CFG.MAX_LENGTH)
test_dataset = LLMPreferenceDataset(test_df, tokenizer, CFG.MAX_LENGTH, is_test=True)

train_loader = DataLoader(train_dataset, batch_size=CFG.BATCH_SIZE, shuffle=True, num_workers=2)
val_loader = DataLoader(val_dataset, batch_size=CFG.BATCH_SIZE, shuffle=False, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=CFG.BATCH_SIZE, shuffle=False, num_workers=2)

# %%
# --- Модель ---
model_config = AutoConfig.from_pretrained(
    CFG.MODEL_NAME, 
    num_labels=CFG.NUM_CLASSES
)

model = AutoModelForSequenceClassification.from_pretrained(
        CFG.MODEL_NAME,
        config=model_config
    )

model.to(CFG.DEVICE)

# --- Оптимизатор и планировщик ---
optimizer = AdamW(
    params=model.parameters(),      
    lr=CFG.LEARNING_RATE,                      
    betas=(0.9, 0.999),          
    eps=1e-8,                      
    weight_decay=CFG.WEIGHT_DECAY,
    amsgrad=False                 
)
num_training_steps = len(train_loader) * CFG.EPOCHS
num_warmup_steps = int(CFG.WARMUP_RATIO * num_training_steps)

scheduler = get_linear_schedule_with_warmup(
    optimizer,
    num_warmup_steps=num_warmup_steps,
    num_training_steps=num_training_steps
)

criterion = nn.CrossEntropyLoss() #
# Out:
# 2025-05-25 19:03:03.686087: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748199783.859366      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748199783.908869      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Some weights of ModernBertForSequenceClassification were not initialized from the model checkpoint at /kaggle/input/modernbert/transformers/base/1/modernbert-base and are newly initialized: ['classifier.bias', 'classifier.weight', 'head.dense.weight', 'head.norm.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# --- Функции обучения и оценки ---
def train_epoch(model, data_loader, optimizer, scheduler, device, criterion):
    model.train()
    total_loss = 0
    for batch_idx, batch in enumerate(data_loader):
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['labels'].to(device)

        optimizer.zero_grad()
        outputs = model(input_ids, attention_mask=attention_mask, labels=labels)        
        logits = outputs.logits
        loss = criterion(logits, labels)
        
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0) # Градиентный клиппинг
        optimizer.step()
        scheduler.step()

        total_loss += loss.item()
        
        if batch_idx % 100 == 0: # Логирование каждые 100 батчей
            print(f"  Batch {batch_idx}/{len(data_loader)}, Train Loss: {loss.item():.4f}")

    return total_loss / len(data_loader)

def evaluate_epoch(model, data_loader, device, criterion):
    model.eval()
    total_loss = 0
    all_preds_probs = []
    all_labels = []

    with torch.no_grad():
        for batch in data_loader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)

            outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
            # loss = outputs.loss
            
            logits = outputs.logits
            loss = criterion(logits, labels)

            total_loss += loss.item()
            
            probs = torch.softmax(logits, dim=1).cpu().numpy()
            all_preds_probs.extend(probs)
            all_labels.extend(labels.cpu().numpy())

    avg_loss = total_loss / len(data_loader)
    # Важно: log_loss ожидает вероятности и метки в правильном порядке
    # Убедитесь, что классы в probs соответствуют порядку 0, 1, 2 (winner_a, winner_b, winner_tie)
    # Если label_mapping был {a:0, b:1, tie:2}, то все в порядке
    competition_log_loss = log_loss(all_labels, all_preds_probs, labels=[0, 1, 2])

    return avg_loss, competition_log_loss

# %%
# --- Цикл обучения ---
best_val_log_loss = float('inf')
best_model_path = os.path.join(CFG.OUTPUT_DIR, f"{CFG.MODEL_NAME.replace('/', '_')}_best.bin")

for epoch in range(CFG.EPOCHS):
    print(f"--- Epoch {epoch+1}/{CFG.EPOCHS} ---")
    train_loss = train_epoch(model, train_loader, optimizer, scheduler, CFG.DEVICE, criterion)
    val_loss, val_log_loss = evaluate_epoch(model, val_loader, CFG.DEVICE, criterion)

    print(f"Epoch {epoch+1} Summary: ")
    print(f"  Train Loss: {train_loss:.4f}")
    print(f"  Val Loss: {val_loss:.4f}")
    print(f"  Val LogLoss (Competition Metric): {val_log_loss:.4f}")

    if val_log_loss < best_val_log_loss:
        best_val_log_loss = val_log_loss
        torch.save(model.state_dict(), best_model_path)
        print(f"  New best model saved to {best_model_path} with LogLoss: {val_log_loss:.4f}")
    
    torch.cuda.empty_cache()
    gc.collect()

print(f"--- Training Finished ---")
print(f"Best Validation LogLoss: {best_val_log_loss:.4f}")
# Out:
# --- Epoch 1/2 ---
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233] WON'T CONVERT compiled_embeddings /usr/local/lib/python3.11/dist-packages/transformers/models/modernbert/modeling_modernbert.py line 212
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233] due to:
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233] Traceback (most recent call last):
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 1164, in __call__
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     result = self._inner_convert(
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]              ^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 547, in __call__
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     return _compile(
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 986, in _compile
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 715, in compile_inner
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     return _compile_inner(code, one_graph, hooks, transform)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_utils_internal.py", line 95, in wrapper_function
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     return function(*args, **kwargs)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 750, in _compile_inner
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     out_code = transform_code_object(code, transform)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/bytecode_transformation.py", line 1361, in transform_code_object
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     transformations(instructions, code_options)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 231, in _fn
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     return fn(*args, **kwargs)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 662, in transform
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     tracer.run()
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 2868, in run
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     super().run()
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 1052, in run
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     while self.step():
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]           ^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 962, in step
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     self.dispatch_table[inst.opcode](self, inst)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 3048, in RETURN_VALUE
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     self._return(inst)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 3033, in _return
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     self.output.compile_subgraph(
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/output_graph.py", line 1101, in compile_subgraph
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     self.compile_and_call_fx_graph(
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/output_graph.py", line 1382, in compile_and_call_fx_graph
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     compiled_fn = self.call_user_compiler(gm)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/output_graph.py", line 1432, in call_user_compiler
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     return self._call_user_compiler(gm)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/output_graph.py", line 1483, in _call_user_compiler
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     raise BackendCompilerFailed(self.compiler_fn, e).with_traceback(
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/output_graph.py", line 1462, in _call_user_compiler
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/repro/after_dynamo.py", line 130, in __call__
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     compiled_gm = compiler_fn(gm, example_inputs)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/__init__.py", line 2340, in __call__
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     return compile_fx(model_, inputs_, config_patches=self.config)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 1863, in compile_fx
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     return aot_autograd(
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/backends/common.py", line 83, in __call__
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 1155, in aot_module_simplified
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     compiled_fn = dispatch_and_compile()
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 1131, in dispatch_and_compile
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     compiled_fn, _ = create_aot_dispatcher_function(
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 580, in create_aot_dispatcher_function
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     return _create_aot_dispatcher_function(
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 830, in _create_aot_dispatcher_function
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     compiled_fn, fw_metadata = compiler_fn(
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]                                ^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/_aot_autograd/jit_compile_runtime_wrappers.py", line 678, in aot_dispatch_autograd
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     compiled_fw_func = aot_config.fw_compiler(fw_module, adjusted_flat_args)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 489, in __call__
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     return self.compiler_fn(gm, example_inputs)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 1741, in fw_compiler_base
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     return inner_compile(
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 569, in compile_fx_inner
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     return wrap_compiler_debug(_compile_fx_inner, compiler_name="inductor")(
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/repro/after_aot.py", line 102, in debug_wrapper
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 685, in _compile_fx_inner
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     mb_compiled_graph = fx_codegen_and_compile(
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]                         ^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 1129, in fx_codegen_and_compile
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     return scheme.codegen_and_compile(gm, example_inputs, inputs_to_check, graph_kwargs)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 1044, in codegen_and_compile
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     compiled_fn = graph.compile_to_module().call
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/graph.py", line 2027, in compile_to_module
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     return self._compile_to_module()
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/graph.py", line 2033, in _compile_to_module
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]                                                              ^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/graph.py", line 1964, in codegen
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     self.scheduler = Scheduler(self.operations)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 1798, in __init__
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     self._init(nodes)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 1816, in _init
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 1816, in <listcomp>
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 1947, in create_scheduler_node
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     return SchedulerNode(self, node)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 893, in __init__
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     self._compute_attrs()
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 907, in _compute_attrs
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     group_fn = self.scheduler.get_backend(device).group_fn
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 3441, in get_backend
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     self.backends[device] = self.create_backend(device)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 3428, in create_backend
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     raise RuntimeError(
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233] RuntimeError: Found Tesla P100-PCIE-16GB which is too old to be supported by the triton GPU compiler, which is used as the backend. Triton only supports devices of CUDA Capability >= 7.0, but your device is of CUDA capability 6.0
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233] Traceback (most recent call last):
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 1164, in __call__
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     result = self._inner_convert(
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]              ^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 547, in __call__
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     return _compile(
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 986, in _compile
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 715, in compile_inner
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     return _compile_inner(code, one_graph, hooks, transform)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_utils_internal.py", line 95, in wrapper_function
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     return function(*args, **kwargs)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 750, in _compile_inner
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     out_code = transform_code_object(code, transform)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/bytecode_transformation.py", line 1361, in transform_code_object
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     transformations(instructions, code_options)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 231, in _fn
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     return fn(*args, **kwargs)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 662, in transform
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     tracer.run()
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 2868, in run
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     super().run()
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 1052, in run
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     while self.step():
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]           ^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 962, in step
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     self.dispatch_table[inst.opcode](self, inst)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 3048, in RETURN_VALUE
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     self._return(inst)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 3033, in _return
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     self.output.compile_subgraph(
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/output_graph.py", line 1101, in compile_subgraph
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     self.compile_and_call_fx_graph(
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/output_graph.py", line 1382, in compile_and_call_fx_graph
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     compiled_fn = self.call_user_compiler(gm)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/output_graph.py", line 1432, in call_user_compiler
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     return self._call_user_compiler(gm)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/output_graph.py", line 1483, in _call_user_compiler
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     raise BackendCompilerFailed(self.compiler_fn, e).with_traceback(
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/output_graph.py", line 1462, in _call_user_compiler
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/repro/after_dynamo.py", line 130, in __call__
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     compiled_gm = compiler_fn(gm, example_inputs)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/__init__.py", line 2340, in __call__
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     return compile_fx(model_, inputs_, config_patches=self.config)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 1863, in compile_fx
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     return aot_autograd(
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/backends/common.py", line 83, in __call__
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 1155, in aot_module_simplified
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     compiled_fn = dispatch_and_compile()
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 1131, in dispatch_and_compile
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     compiled_fn, _ = create_aot_dispatcher_function(
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 580, in create_aot_dispatcher_function
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     return _create_aot_dispatcher_function(
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 830, in _create_aot_dispatcher_function
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     compiled_fn, fw_metadata = compiler_fn(
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]                                ^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/_aot_autograd/jit_compile_runtime_wrappers.py", line 678, in aot_dispatch_autograd
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     compiled_fw_func = aot_config.fw_compiler(fw_module, adjusted_flat_args)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 489, in __call__
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     return self.compiler_fn(gm, example_inputs)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 1741, in fw_compiler_base
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     return inner_compile(
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 569, in compile_fx_inner
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     return wrap_compiler_debug(_compile_fx_inner, compiler_name="inductor")(
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/repro/after_aot.py", line 102, in debug_wrapper
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 685, in _compile_fx_inner
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     mb_compiled_graph = fx_codegen_and_compile(
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]                         ^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 1129, in fx_codegen_and_compile
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     return scheme.codegen_and_compile(gm, example_inputs, inputs_to_check, graph_kwargs)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 1044, in codegen_and_compile
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     compiled_fn = graph.compile_to_module().call
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/graph.py", line 2027, in compile_to_module
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     return self._compile_to_module()
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/graph.py", line 2033, in _compile_to_module
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]                                                              ^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/graph.py", line 1964, in codegen
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     self.scheduler = Scheduler(self.operations)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 1798, in __init__
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     self._init(nodes)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 1816, in _init
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 1816, in <listcomp>
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 1947, in create_scheduler_node
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     return SchedulerNode(self, node)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 893, in __init__
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     self._compute_attrs()
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 907, in _compute_attrs
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     group_fn = self.scheduler.get_backend(device).group_fn
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 3441, in get_backend
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     self.backends[device] = self.create_backend(device)
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 3428, in create_backend
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]     raise RuntimeError(
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233] RuntimeError: Found Tesla P100-PCIE-16GB which is too old to be supported by the triton GPU compiler, which is used as the backend. Triton only supports devices of CUDA Capability >= 7.0, but your device is of CUDA capability 6.0
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W0525 19:03:28.797000 19 torch/_dynamo/convert_frame.py:1233]
# W0525 19:03:29.624000 19 torch/_inductor/utils.py:1137] [1/0] Not enough SMs to use max_autotune_gemm mode
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233] WON'T CONVERT compiled_mlp /usr/local/lib/python3.11/dist-packages/transformers/models/modernbert/modeling_modernbert.py line 531
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233] due to:
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233] Traceback (most recent call last):
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 1164, in __call__
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]     result = self._inner_convert(
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]              ^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 547, in __call__
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]     return _compile(
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 986, in _compile
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 715, in compile_inner
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]     return _compile_inner(code, one_graph, hooks, transform)
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_utils_internal.py", line 95, in wrapper_function
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]     return function(*args, **kwargs)
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 750, in _compile_inner
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]     out_code = transform_code_object(code, transform)
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/bytecode_transformation.py", line 1361, in transform_code_object
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]     transformations(instructions, code_options)
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 231, in _fn
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]     return fn(*args, **kwargs)
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 662, in transform
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]     tracer.run()
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 2868, in run
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]     super().run()
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 1052, in run
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]     while self.step():
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]           ^^^^^^^^^^^
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 962, in step
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]     self.dispatch_table[inst.opcode](self, inst)
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 3048, in RETURN_VALUE
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]     self._return(inst)
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 3033, in _return
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]     self.output.compile_subgraph(
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/output_graph.py", line 1101, in compile_subgraph
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]     self.compile_and_call_fx_graph(
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/output_graph.py", line 1382, in compile_and_call_fx_graph
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]     compiled_fn = self.call_user_compiler(gm)
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/output_graph.py", line 1432, in call_user_compiler
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]     return self._call_user_compiler(gm)
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/output_graph.py", line 1483, in _call_user_compiler
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]     raise BackendCompilerFailed(self.compiler_fn, e).with_traceback(
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/output_graph.py", line 1462, in _call_user_compiler
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/repro/after_dynamo.py", line 130, in __call__
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]     compiled_gm = compiler_fn(gm, example_inputs)
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/__init__.py", line 2340, in __call__
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]     return compile_fx(model_, inputs_, config_patches=self.config)
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 1863, in compile_fx
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]     return aot_autograd(
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/backends/common.py", line 83, in __call__
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 1155, in aot_module_simplified
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]     compiled_fn = dispatch_and_compile()
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 1131, in dispatch_and_compile
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]     compiled_fn, _ = create_aot_dispatcher_function(
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 580, in create_aot_dispatcher_function
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]     return _create_aot_dispatcher_function(
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 830, in _create_aot_dispatcher_function
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]     compiled_fn, fw_metadata = compiler_fn(
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]                                ^^^^^^^^^^^^
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/_aot_autograd/jit_compile_runtime_wrappers.py", line 678, in aot_dispatch_autograd
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]     compiled_fw_func = aot_config.fw_compiler(fw_module, adjusted_flat_args)
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 489, in __call__
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]     return self.compiler_fn(gm, example_inputs)
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 1741, in fw_compiler_base
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]     return inner_compile(
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 569, in compile_fx_inner
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]     return wrap_compiler_debug(_compile_fx_inner, compiler_name="inductor")(
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/repro/after_aot.py", line 102, in debug_wrapper
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 685, in _compile_fx_inner
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]     mb_compiled_graph = fx_codegen_and_compile(
# W0525 19:03:29.693000 19 torch/_dynamo/convert_frame.py:1233]                         ^^^^^^^^^^^^^^^^^^^^^^^
# ...
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]     compiled_gm = compiler_fn(gm, example_inputs)
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/__init__.py", line 2340, in __call__
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]     return compile_fx(model_, inputs_, config_patches=self.config)
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 1863, in compile_fx
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]     return aot_autograd(
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/backends/common.py", line 83, in __call__
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 1155, in aot_module_simplified
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]     compiled_fn = dispatch_and_compile()
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 1131, in dispatch_and_compile
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]     compiled_fn, _ = create_aot_dispatcher_function(
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 580, in create_aot_dispatcher_function
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]     return _create_aot_dispatcher_function(
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 830, in _create_aot_dispatcher_function
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]     compiled_fn, fw_metadata = compiler_fn(
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]                                ^^^^^^^^^^^^
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/_aot_autograd/jit_compile_runtime_wrappers.py", line 678, in aot_dispatch_autograd
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]     compiled_fw_func = aot_config.fw_compiler(fw_module, adjusted_flat_args)
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 489, in __call__
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]     return self.compiler_fn(gm, example_inputs)
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 1741, in fw_compiler_base
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]     return inner_compile(
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 569, in compile_fx_inner
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]     return wrap_compiler_debug(_compile_fx_inner, compiler_name="inductor")(
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/repro/after_aot.py", line 102, in debug_wrapper
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 685, in _compile_fx_inner
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]     mb_compiled_graph = fx_codegen_and_compile(
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]                         ^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 1129, in fx_codegen_and_compile
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]     return scheme.codegen_and_compile(gm, example_inputs, inputs_to_check, graph_kwargs)
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 1044, in codegen_and_compile
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]     compiled_fn = graph.compile_to_module().call
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/graph.py", line 2027, in compile_to_module
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]     return self._compile_to_module()
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/graph.py", line 2033, in _compile_to_module
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]                                                              ^^^^^^^^^^^^^^
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/graph.py", line 1964, in codegen
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]     self.scheduler = Scheduler(self.operations)
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 1798, in __init__
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]     self._init(nodes)
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 1816, in _init
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 1816, in <listcomp>
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 1947, in create_scheduler_node
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]     return SchedulerNode(self, node)
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 893, in __init__
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]     self._compute_attrs()
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 907, in _compute_attrs
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]     group_fn = self.scheduler.get_backend(device).group_fn
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 3441, in get_backend
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]     self.backends[device] = self.create_backend(device)
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 3428, in create_backend
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]     raise RuntimeError(
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233] RuntimeError: Found Tesla P100-PCIE-16GB which is too old to be supported by the triton GPU compiler, which is used as the backend. Triton only supports devices of CUDA Capability >= 7.0, but your device is of CUDA capability 6.0
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W0525 19:03:30.426000 19 torch/_dynamo/convert_frame.py:1233]
#   Batch 0/5748, Train Loss: 1.1410
#   Batch 100/5748, Train Loss: 1.1956
#   Batch 200/5748, Train Loss: 1.0706
#   Batch 300/5748, Train Loss: 0.9472
#   Batch 400/5748, Train Loss: 1.0984
#   Batch 500/5748, Train Loss: 1.4391
#   Batch 600/5748, Train Loss: 1.0269
#   Batch 700/5748, Train Loss: 1.1317
#   Batch 800/5748, Train Loss: 1.0631
#   Batch 900/5748, Train Loss: 1.2957
#   Batch 1000/5748, Train Loss: 1.1350
#   Batch 1100/5748, Train Loss: 1.2368
#   Batch 1200/5748, Train Loss: 1.2073
#   Batch 1300/5748, Train Loss: 1.1618
#   Batch 1400/5748, Train Loss: 1.0965
#   Batch 1500/5748, Train Loss: 1.0170
#   Batch 1600/5748, Train Loss: 1.0871
#   Batch 1700/5748, Train Loss: 1.1295
#   Batch 1800/5748, Train Loss: 1.1552
#   Batch 1900/5748, Train Loss: 1.2208
#   Batch 2000/5748, Train Loss: 1.1278
#   Batch 2100/5748, Train Loss: 1.2109
#   Batch 2200/5748, Train Loss: 1.0389
#   Batch 2300/5748, Train Loss: 1.3978
#   Batch 2400/5748, Train Loss: 1.3001
#   Batch 2500/5748, Train Loss: 1.0444
#   Batch 2600/5748, Train Loss: 1.0468
#   Batch 2700/5748, Train Loss: 1.2345
#   Batch 2800/5748, Train Loss: 1.1206
#   Batch 2900/5748, Train Loss: 1.0968
#   Batch 3000/5748, Train Loss: 0.9566
#   Batch 3100/5748, Train Loss: 1.2440
#   Batch 3200/5748, Train Loss: 1.1200
#   Batch 3300/5748, Train Loss: 1.0523
#   Batch 3400/5748, Train Loss: 1.1033
#   Batch 3500/5748, Train Loss: 1.3368
#   Batch 3600/5748, Train Loss: 0.9072
#   Batch 3700/5748, Train Loss: 1.1427
#   Batch 3800/5748, Train Loss: 1.0370
#   Batch 3900/5748, Train Loss: 1.1439
#   Batch 4000/5748, Train Loss: 1.0989
#   Batch 4100/5748, Train Loss: 1.2217
#   Batch 4200/5748, Train Loss: 1.1512
#   Batch 4300/5748, Train Loss: 1.1569
#   Batch 4400/5748, Train Loss: 1.0526
#   Batch 4500/5748, Train Loss: 1.0183
#   Batch 4600/5748, Train Loss: 1.1703
#   Batch 4700/5748, Train Loss: 1.0310
#   Batch 4800/5748, Train Loss: 1.2198
#   Batch 4900/5748, Train Loss: 1.1325
#   Batch 5000/5748, Train Loss: 1.0732
#   Batch 5100/5748, Train Loss: 1.0909
#   Batch 5200/5748, Train Loss: 1.1245
#   Batch 5300/5748, Train Loss: 1.0393
#   Batch 5400/5748, Train Loss: 1.1071
#   Batch 5500/5748, Train Loss: 1.1216
#   Batch 5600/5748, Train Loss: 1.1044
#   Batch 5700/5748, Train Loss: 1.0990
# Epoch 1 Summary:
#   Train Loss: 1.1080
#   Val Loss: 1.0908
#   Val LogLoss (Competition Metric): 1.0908
#   New best model saved to /kaggle/working/_kaggle_input_modernbert_transformers_base_1_modernbert-base_best.bin with LogLoss: 1.0908
# --- Epoch 2/2 ---
#   Batch 0/5748, Train Loss: 1.0634
#   Batch 100/5748, Train Loss: 1.1327
#   Batch 200/5748, Train Loss: 0.9593
#   Batch 300/5748, Train Loss: 1.1637
#   Batch 400/5748, Train Loss: 1.1463
#   Batch 500/5748, Train Loss: 1.1804
#   Batch 600/5748, Train Loss: 0.9866
#   Batch 700/5748, Train Loss: 1.0383
#   Batch 800/5748, Train Loss: 1.1128
#   Batch 900/5748, Train Loss: 1.0790
#   Batch 1000/5748, Train Loss: 1.0409
#   Batch 1100/5748, Train Loss: 1.2898
#   Batch 1200/5748, Train Loss: 1.0158
#   Batch 1300/5748, Train Loss: 1.0504
#   Batch 1400/5748, Train Loss: 1.1364
#   Batch 1500/5748, Train Loss: 1.1585
#   Batch 1600/5748, Train Loss: 1.0805
#   Batch 1700/5748, Train Loss: 1.0175
#   Batch 1800/5748, Train Loss: 1.0401
#   Batch 1900/5748, Train Loss: 1.1387
#   Batch 2000/5748, Train Loss: 1.1189
#   Batch 2100/5748, Train Loss: 0.9186
#   Batch 2200/5748, Train Loss: 1.2061
#   Batch 2300/5748, Train Loss: 1.1185
#   Batch 2400/5748, Train Loss: 1.1084
#   Batch 2500/5748, Train Loss: 1.0706
#   Batch 2600/5748, Train Loss: 1.1885
#   Batch 2700/5748, Train Loss: 0.8399
#   Batch 2800/5748, Train Loss: 1.1335
#   Batch 2900/5748, Train Loss: 1.0392
#   Batch 3000/5748, Train Loss: 1.1224
#   Batch 3100/5748, Train Loss: 1.0556
#   Batch 3200/5748, Train Loss: 0.6899
#   Batch 3300/5748, Train Loss: 0.8673
#   Batch 3400/5748, Train Loss: 1.1743
#   Batch 3500/5748, Train Loss: 1.0851
#   Batch 3600/5748, Train Loss: 1.0423
#   Batch 3700/5748, Train Loss: 0.7863
#   Batch 3800/5748, Train Loss: 1.1330
#   Batch 3900/5748, Train Loss: 0.8135
#   Batch 4000/5748, Train Loss: 1.2351
#   Batch 4100/5748, Train Loss: 0.9033
#   Batch 4200/5748, Train Loss: 0.8731
#   Batch 4300/5748, Train Loss: 1.1076
#   Batch 4400/5748, Train Loss: 1.5008
#   Batch 4500/5748, Train Loss: 1.0446
#   Batch 4600/5748, Train Loss: 1.0887
#   Batch 4700/5748, Train Loss: 1.3183
#   Batch 4800/5748, Train Loss: 1.1209
#   Batch 4900/5748, Train Loss: 0.8840
#   Batch 5000/5748, Train Loss: 0.9219
#   Batch 5100/5748, Train Loss: 1.0244
#   Batch 5200/5748, Train Loss: 1.0859
#   Batch 5300/5748, Train Loss: 1.1565
#   Batch 5400/5748, Train Loss: 0.9722
#   Batch 5500/5748, Train Loss: 1.0296
#   Batch 5600/5748, Train Loss: 1.2202
#   Batch 5700/5748, Train Loss: 1.1685
# Epoch 2 Summary:
#   Train Loss: 1.0578
#   Val Loss: 1.0344
#   Val LogLoss (Competition Metric): 1.0344
#   New best model saved to /kaggle/working/_kaggle_input_modernbert_transformers_base_1_modernbert-base_best.bin with LogLoss: 1.0344
# --- Training Finished ---
# Best Validation LogLoss: 1.0344

# %%
# --- Предсказание на тестовых данных ---
# Загружаем лучшую модель
model.load_state_dict(torch.load(best_model_path))
model.eval()

test_preds_probs = []
test_ids_ordered = []

with torch.no_grad():
    for batch_data, batch_ids in test_loader:
        input_ids = batch_data['input_ids'].to(CFG.DEVICE)
        attention_mask = batch_data['attention_mask'].to(CFG.DEVICE)
        
        outputs = model(input_ids, attention_mask=attention_mask)
        logits = outputs.logits
        probs = torch.softmax(logits, dim=1).cpu().numpy()
        
        test_preds_probs.extend(probs)
        test_ids_ordered.extend(batch_ids.cpu().tolist())

# %%
# --- Формирование файла сабмита ---
submission_df = pd.DataFrame(test_preds_probs, columns=['winner_model_a', 'winner_model_b', 'winner_tie'])
submission_df['id'] = test_ids_ordered 

submission_df = submission_df[['id', 'winner_model_a', 'winner_model_b', 'winner_tie']]

submission_path = os.path.join(CFG.OUTPUT_DIR, 'submission.csv')
submission_df.to_csv(submission_path, index=False)

print(f"Submission file created at: {submission_path}")
print("Top 5 rows of submission:")
print(submission_df.head())
# Out:
# Submission file created at: /kaggle/working/submission.csv
# Top 5 rows of submission:
#         id  winner_model_a  winner_model_b  winner_tie
# 0   136060        0.215080        0.200190    0.584730
# 1   211333        0.427445        0.291357    0.281198
# 2  1233961        0.355653        0.291164    0.353183
